# %%
import numpy as np
from numpy import zeros
from numpy import ones
from numpy import expand_dims
from numpy import hstack
from numpy.random import randn
from numpy.random import randint
from keras.datasets.mnist import load_data
from keras.optimizers import Adam
from keras.initializers import RandomNormal
from keras.utils import to_categorical
from keras.models import Model
from keras import layers
import tensorflow_datasets as tfds
import tensorflow as tf
from matplotlib import pyplot
import zipfile
from PIL import Image
from math import sqrt
from numpy import asarray
from numpy.random import random
from numpy.random import choice

from keras.models import load_model
import os
class InfoGAN:
    def __init__(self):
        
        # number of values for the categorical control code
        self.n_cat = 10
        self.dim_cat=10
        # size of the latent space
        self.latent_dim = 128
        #Define size of generator input
        self.gen_input_size = self.latent_dim + self.n_cat*self.dim_cat
        self.batch_size=128
        self.kernel_init = RandomNormal(stddev=0.02)

    
         
    def load_MNIST(self):
        ds, ds_info = tfds.load('mnist', split='train', with_info=True,as_supervised=True,batch_size=-1)
        shape=ds_info.features['image'].shape
        (img_train, label_train)=tfds.as_numpy(ds)
        img_train=img_train.astype('float32')/255
        return img_train,ds, ds_info, shape
    
    def load_SVHN(self):
        ds, ds_info = tfds.load('svhn_cropped', split='train', with_info=True,as_supervised=True,batch_size=-1)
        shape=ds_info.features['image'].shape
        (img_train, label_train)=tfds.as_numpy(ds)
        img_train=img_train.astype('float32')/255
        return img_train,ds, ds_info, shape
    
    def load_CELEBA(self):
        imgs = []
        path = "../input/celeba/img_align_celeba/"
        valid_images = [".jpg",".gif",".png",".tga"]
        for f in os.listdir(path)[0:60000]:
            ext = os.path.splitext(f)[1]
            if ext.lower() not in valid_images:
                continue
            image=Image.open(os.path.join(path,f))
            image=image.resize((64,64),resample=Image.LANCZOS)
            imgs.append(np.array(image))

        imgs=np.array(imgs)
        imgs=(imgs.astype('float32')-127.5)/127.5
        shape=(imgs.shape[1],imgs.shape[2],imgs.shape[3])
        return imgs,shape
        

    def show_real_examples(self,ds, ds_info):
        fig = tfds.show_examples(ds, ds_info)

    #Define the generator model:
    def get_generator(self,shape):
        input_latent = layers.Input(shape=(self.gen_input_size))
        
        #The various datasets have various sizes and #channels so the dimension of the generator needs to be variable
        res=int(shape[0]/8)
        depth=int(shape[-1])
        
        n_nodes = 512 * res * res

        g = layers.Dense(n_nodes)(input_latent)
        g = layers.LeakyReLU(alpha=0.2)(g)
        g = layers.BatchNormalization()(g)
        g = layers.Reshape((res, res, 512))(g)

        g = layers.Conv2D(128, 4, padding='same',kernel_initializer=self.kernel_init)(g)
        g = layers.LeakyReLU(alpha=0.2)(g)
        g = layers.BatchNormalization()(g)

        g = layers.Conv2DTranspose(128, 4, strides=(2,2), padding='same',kernel_initializer=self.kernel_init)(g)
        g = layers.LeakyReLU(alpha=0.2)(g)
        g = layers.BatchNormalization()(g)
        
        g = layers.Conv2DTranspose(64, 4, strides=(2,2), padding='same',kernel_initializer=self.kernel_init)(g)
        g = layers.LeakyReLU(alpha=0.2)(g)
        g = layers.BatchNormalization()(g)
        
        g = layers.Conv2DTranspose(depth, 4, strides=(2,2), padding='same',kernel_initializer=self.kernel_init)(g)
        # Tanh output
        output_layer = layers.Activation('tanh')(g)
        # define the generator model
        gen_model = Model(input_latent, output_layer)
        return gen_model
    
    
    def get_discr_q(self,input_shape):
        input_image=layers.Input(shape=input_shape)


        l=layers.Conv2D(64, 4, strides=(2,2), padding='same',kernel_initializer=self.kernel_init)(input_image)
        l=layers.LeakyReLU(alpha=0.2)(l)
        l=layers.BatchNormalization()(l)
        
        l=layers.Conv2D(128, 4, strides=(2,2), padding='same',kernel_initializer=self.kernel_init)(l)
        l=layers.LeakyReLU(alpha=0.2)(l)
        l=layers.BatchNormalization()(l)
        
        l=layers.Conv2D(256, 4, strides=(2,2), padding='same',kernel_initializer=self.kernel_init)(l)
        l=layers.LeakyReLU(alpha=0.2)(l)
        l=layers.BatchNormalization()(l)
    
        l=layers.Conv2D(512, 4, strides=(2,2), padding='same',kernel_initializer=self.kernel_init)(l)
        l=layers.LeakyReLU(alpha=0.2)(l)
        l=layers.BatchNormalization()(l)
        
        l=layers.Conv2D(1024, 4, strides=(2,2), padding='same',kernel_initializer=self.kernel_init)(l)
        l=layers.LeakyReLU(alpha=0.2)(l)
        l=layers.BatchNormalization()(l)
        
        

        l=layers.Flatten()(l)
        #Classification head of the discriminator
        out=layers.Dense(1,activation='sigmoid')(l)
        discr_model = Model(input_image, out)
        discr_model.compile(loss='binary_crossentropy', optimizer=Adam(lr=4e-4, beta_1=0.5))
        # create q model layers
        q = layers.Dense(128)(l)
        q = layers.BatchNormalization()(q)
        q = layers.LeakyReLU(alpha=0.2)(q)
        # q model output
        out_codes_discrete = layers.Dense(self.n_cat*self.dim_cat, activation='softmax')(q)
        #out
        # define q model
        q_model = Model(input_image, out_codes_discrete)
        return discr_model, q_model
    

    def infogan(self,gen_model, discr_model, q_model):
        # make weights in the discriminator (some shared with the q model) as not trainable
        for layer in discr_model.layers:
            if not isinstance(layer, layers.BatchNormalization):
                layer.trainable = False
        # connect g outputs to d inputs
        discr_output = discr_model(gen_model.output)
        # connect g outputs to q inputs
        q_output = q_model(gen_model.output)
        # define composite model
        infogan_model = Model(gen_model.input, [discr_output, q_output])
        # compile model
        opt = Adam(lr=1e-4, beta_1=0.5)
        infogan_model.compile(loss=['binary_crossentropy', 'categorical_crossentropy'], optimizer=opt)
        return infogan_model
    
    # example of smoothing class=1 to [0.7, 1.2]
    def smooth_positive_labels(self,y):
        return y - 0.1 * random(y.shape)
        # select real samples
        
    def smooth_negative_labels(self,y):
        return y + random(y.shape) * 0.1
    
    def noisy_labels(self,y, p_flip):
        # determine the number of labels to flip
        n_select = int(p_flip * y.shape[0])
        # choose labels to flip
        flip_ix = choice([i for i in range(y.shape[0])], size=n_select)
        # invert the labels in place
        y[flip_ix] = 1 - y[flip_ix]
        return y
 
        
    def generate_real_samples(self,dataset, n_samples):
        # choose random instances
        ix = randint(0, dataset.shape[0], n_samples)
        # select images and labels
        X = dataset[ix]
        # generate class labels
        y = ones((n_samples, 1))
        #y = self.smooth_positive_labels(y)
        y = self.noisy_labels(y, 0.05)
        return X, y
    
    # generate points in latent space as input for the generator
    def generate_noise(self, n_samples):
        # generate points in the latent space
        z_latent=randn(n_samples,self.latent_dim)
        # generate categorical one-hot codes
        cat_codes=np.eye(self.dim_cat)[np.random.choice(self.dim_cat, self.n_cat)].reshape(1,self.n_cat*self.dim_cat)
        for i in range(0,n_samples-1):
            
            cat_codes=np.vstack((cat_codes,np.eye(self.dim_cat)[np.random.choice(self.dim_cat, self.n_cat)].reshape(1,self.n_cat*self.dim_cat)))
        # concatenate latent points and control codes
        z_input = hstack((z_latent, cat_codes))
        return [z_input, cat_codes]
    
    # use the generator to generate n fake examples, with class labels
    def generate_fake_samples(self,generator, n_samples):
        # generate points in latent space and control codes
        z_input, _ = self.generate_noise(n_samples)
        # predict outputs
        images = generator.predict(z_input)
        # create class labels
        y = zeros((n_samples, 1))
        #y = self.smooth_negative_labels(y)
        y = self.noisy_labels(y, 0.05)
        return images, y
    
    def summarize_performance(self,step, gen_model, gan_model, n_samples=100):
        # prepare fake examples
        X, _ = self.generate_fake_samples(gen_model, n_samples)
        X = (X + 1) / 2.0
        # plot images
        for i in range(n_samples):
            # define subplot
            pyplot.subplot(10, 10, 1 + i)
            # turn off axis
            pyplot.axis('off')
            # plot raw pixel data
            if X.shape[-1]==1:
              pyplot.imshow(X[i, :, :, 0], cmap='gray_r')
            else:
              pyplot.imshow(X[i, :, :, :])
        # save plot to file
        filename1 = 'generated_plot_%04d.png' % (step+1)
        pyplot.savefig(filename1)
        pyplot.close()
        # save the generator model
        filename2 = 'model_%04d.h5' % (step+1)
        gen_model.save(filename2)
        # save the gan model
        filename3 = 'gan_model_%04d.h5' % (step+1)
        gan_model.save(filename3)
        print('>Saved: %s, %s, and %s' % (filename1, filename2, filename3))
        
    # train the generator and discriminator
    def train(self,gen_model, discr_model, infogan_model, dataset, n_epochs=100):
        # calculate the number of batches per training epoch
        bat_per_epo = int(len(dataset)/self.batch_size)
        print("Batch per epoch: ",bat_per_epo)
        # calculate the number of training iterations
        n_steps = int(bat_per_epo * n_epochs)
        print("N_Steps:",n_steps)
        saved_metrics={'d_loss1':[],'d_loss2':[],'g_1':[],'g_2':[]}
        # manually enumerate epochs
        for i in range(n_steps):
            X_real, y_real = self.generate_real_samples(dataset, int(self.batch_size))
            # update discriminator and q model weights
            d_loss1 = discr_model.train_on_batch(X_real, y_real)
            # generate 'fake' examples
            X_fake, y_fake = self.generate_fake_samples(gen_model, int(self.batch_size))
            # update discriminator model weights
            d_loss2 = discr_model.train_on_batch(X_fake, y_fake)
            # prepare points in latent space as input for the generator
            z_input, cat_codes = self.generate_noise(self.batch_size)
            # create inverted labels for the fake samples
            y_gan = ones((self.batch_size, 1))
            # update the g via the d and q error
            _,g_1,g_2  = infogan_model.train_on_batch(z_input, [y_gan, cat_codes])
            saved_metrics['d_loss1'].append(d_loss1)
            saved_metrics['d_loss2'].append(d_loss2)
            saved_metrics['g_1'].append(g_1)
            saved_metrics['g_2'].append(g_2)
            # summarize loss on this batch
            if(i+1)%5==0:
              print('>%d, d[%.3f,%.3f], g[%.3f] q[%.3f]' % (i+1, d_loss1, d_loss2, g_1, g_2 ))
            # evaluate the model performance every 'epoch'
            if (i+1) % (bat_per_epo * 10) == 0:
                self.summarize_performance(i, gen_model, infogan_model)
                pyplot.plot(saved_metrics['g_1'], 'r',label='gen')  
                pyplot.plot(saved_metrics['d_loss1'], 'b',label='disc_real') 
                pyplot.plot(saved_metrics['d_loss2'] ,'g',label='disc_fake') 
                pyplot.plot(saved_metrics['g_2'],'y',label='q')
                pyplot.legend() 
                pyplot.grid()
                pyplot.title('Learning curves of GAN')
                pyplot.savefig('learning_curves_{}'.format(i))
                pyplot.close()

# %%
gan=InfoGAN()
img_train,shape=gan.load_CELEBA()
gen_model=gan.get_generator(shape)
discr_model,q_model=gan.get_discr_q(shape)
infogan_model=gan.infogan(gen_model, discr_model, q_model)

# %%
gan.train(gen_model, discr_model, infogan_model, img_train, n_epochs=100)
# Out:
# Batch per epoch:  468
# N_Steps: 46800
# >5, d[1.480,0.396], g[2.793] q[48.481]
# >10, d[1.543,0.597], g[0.761] q[48.138]
# >15, d[1.336,0.315], g[0.263] q[47.491]
# >20, d[0.432,0.617], g[0.428] q[46.691]
# >25, d[0.301,0.509], g[0.164] q[46.700]
# >30, d[0.714,1.014], g[0.092] q[45.637]
# >35, d[0.405,0.738], g[0.186] q[45.123]
# >40, d[0.211,0.232], g[0.223] q[44.780]
# >45, d[0.227,0.217], g[0.119] q[44.191]
# >50, d[0.218,0.197], g[0.070] q[43.555]
# >55, d[0.213,0.183], g[0.072] q[43.043]
# >60, d[0.202,0.201], g[0.065] q[42.431]
# >65, d[0.206,0.175], g[0.080] q[41.852]
# >70, d[0.177,0.201], g[0.100] q[41.473]
# >75, d[0.270,0.179], g[0.026] q[40.914]
# >80, d[0.225,0.192], g[0.081] q[40.653]
# >85, d[0.190,0.182], g[0.075] q[39.667]
# >90, d[0.207,0.193], g[0.046] q[39.393]
# >95, d[0.173,0.224], g[0.088] q[39.239]
# >100, d[0.200,0.199], g[0.061] q[38.786]
# >105, d[0.206,0.200], g[0.040] q[38.558]
# >110, d[0.203,0.203], g[0.059] q[38.306]
# >115, d[0.246,0.210], g[0.034] q[37.598]
# >120, d[0.183,0.199], g[0.040] q[37.441]
# >125, d[0.181,0.184], g[0.078] q[37.175]
# >130, d[0.191,0.186], g[0.071] q[37.251]
# >135, d[0.206,0.199], g[0.095] q[36.948]
# >140, d[0.200,0.184], g[0.043] q[36.532]
# >145, d[0.204,0.209], g[0.064] q[36.538]
# >150, d[0.243,0.190], g[0.053] q[36.124]
# >155, d[0.187,0.192], g[0.048] q[36.271]
# >160, d[0.196,0.191], g[0.086] q[36.176]
# >165, d[0.212,0.191], g[0.044] q[35.923]
# >170, d[0.188,0.188], g[0.085] q[35.565]
# >175, d[0.215,0.199], g[0.065] q[35.840]
# >180, d[0.218,0.196], g[0.054] q[35.423]
# >185, d[0.221,0.200], g[0.045] q[35.536]
# >190, d[0.196,0.192], g[0.020] q[35.309]
# >195, d[0.250,0.226], g[0.041] q[34.937]
# >200, d[0.190,0.209], g[0.033] q[34.958]
# >205, d[0.211,0.202], g[0.050] q[34.696]
# >210, d[0.195,0.201], g[0.034] q[34.825]
# >215, d[0.209,0.188], g[0.045] q[34.569]
# >220, d[0.192,0.177], g[0.029] q[34.592]
# >225, d[0.194,0.178], g[0.039] q[34.779]
# >230, d[0.205,0.178], g[0.062] q[34.550]
# >235, d[0.185,0.195], g[0.030] q[34.495]
# >240, d[0.200,0.194], g[0.015] q[34.335]
# >245, d[0.195,0.193], g[0.051] q[34.073]
# >250, d[0.221,0.212], g[0.021] q[34.037]
# >255, d[0.192,0.197], g[0.050] q[34.046]
# >260, d[0.199,0.192], g[0.037] q[33.709]
# >265, d[0.188,0.198], g[0.055] q[33.764]
# >270, d[0.199,0.198], g[0.038] q[34.006]
# >275, d[0.194,0.201], g[0.025] q[33.783]
# >280, d[0.203,0.198], g[0.031] q[33.951]
# >285, d[0.183,0.203], g[0.027] q[33.697]
# >290, d[0.185,0.200], g[0.027] q[33.782]
# >295, d[0.196,0.204], g[0.046] q[33.510]
# >300, d[0.206,0.174], g[0.064] q[33.521]
# >305, d[0.180,0.195], g[0.031] q[33.430]
# >310, d[0.189,0.190], g[0.011] q[33.527]
# >315, d[0.206,0.221], g[0.054] q[33.090]
# >320, d[0.194,0.217], g[0.030] q[33.156]
# >325, d[0.187,0.189], g[0.060] q[33.226]
# >330, d[0.197,0.201], g[0.035] q[33.266]
# >335, d[0.161,0.147], g[0.027] q[33.250]
# >340, d[0.190,0.197], g[0.034] q[33.435]
# >345, d[0.185,0.197], g[0.049] q[33.428]
# >350, d[0.197,0.203], g[0.051] q[33.192]
# >355, d[0.184,0.219], g[0.034] q[33.174]
# >360, d[0.209,0.209], g[0.035] q[33.012]
# >365, d[0.215,0.198], g[0.039] q[33.236]
# >370, d[0.195,0.220], g[0.081] q[32.939]
# >375, d[0.198,0.188], g[0.043] q[32.955]
# >380, d[0.197,0.180], g[0.054] q[32.939]
# >385, d[0.204,0.193], g[0.067] q[32.887]
# >390, d[0.189,0.148], g[0.048] q[32.831]
# >395, d[0.197,0.221], g[0.046] q[32.908]
# >400, d[0.189,0.196], g[0.047] q[32.954]
# >405, d[0.202,0.216], g[0.050] q[32.562]
# >410, d[0.201,0.207], g[0.055] q[32.710]
# >415, d[0.189,0.176], g[0.100] q[32.694]
# >420, d[0.196,0.191], g[0.070] q[32.548]
# >425, d[0.186,0.216], g[0.093] q[32.570]
# >430, d[0.195,0.188], g[0.065] q[32.526]
# >435, d[0.197,0.196], g[0.042] q[32.454]
# >440, d[0.204,0.182], g[0.038] q[32.578]
# >445, d[0.184,0.220], g[0.041] q[32.490]
# >450, d[0.199,0.207], g[0.048] q[32.824]
# >455, d[0.203,0.193], g[0.032] q[32.592]
# >460, d[0.212,0.225], g[0.031] q[32.681]
# >465, d[0.196,0.164], g[0.041] q[32.651]
# >470, d[0.195,0.196], g[0.056] q[32.452]
# >475, d[0.187,0.209], g[0.064] q[32.449]
# >480, d[0.180,0.183], g[0.093] q[32.844]
# >485, d[0.174,0.214], g[0.062] q[32.772]
# >490, d[0.197,0.208], g[0.108] q[32.460]
# >495, d[0.205,0.227], g[0.034] q[32.461]
# >500, d[0.198,0.222], g[0.062] q[32.873]
# >505, d[0.176,0.171], g[0.510] q[32.988]
# >510, d[0.213,0.239], g[0.195] q[33.219]
# >515, d[0.191,0.357], g[6.592] q[36.620]
# >520, d[0.186,0.148], g[4.452] q[34.398]
# >525, d[0.203,0.244], g[2.321] q[33.775]
# >530, d[0.214,0.388], g[7.008] q[34.615]
# >535, d[0.200,0.226], g[3.012] q[34.501]
# >540, d[0.191,0.193], g[2.882] q[34.373]
# >545, d[0.187,0.289], g[4.290] q[34.652]
# >550, d[0.537,0.330], g[7.007] q[39.103]
# >555, d[0.438,0.213], g[3.257] q[37.303]
# >560, d[0.262,0.263], g[4.456] q[35.617]
# >565, d[0.993,0.639], g[14.316] q[43.574]
# >570, d[0.451,0.494], g[8.230] q[42.072]
# >575, d[0.272,0.243], g[3.091] q[40.486]
# >580, d[0.204,0.215], g[2.786] q[38.711]
# >585, d[0.209,0.168], g[2.326] q[37.859]
# >590, d[0.193,0.192], g[3.255] q[37.712]
# >595, d[0.176,0.208], g[3.940] q[37.584]
# >600, d[0.226,0.283], g[5.140] q[38.205]
# >605, d[0.206,0.221], g[3.037] q[37.328]
# >610, d[0.196,0.199], g[3.187] q[36.834]
# >615, d[0.201,0.208], g[3.068] q[36.115]
# >620, d[0.216,0.195], g[3.278] q[35.612]
# >625, d[0.210,0.210], g[2.974] q[36.083]
# >630, d[0.200,0.213], g[3.486] q[35.700]
# >635, d[0.194,0.197], g[3.460] q[35.769]
# >640, d[0.205,0.207], g[3.328] q[35.671]
# >645, d[0.205,0.188], g[3.562] q[35.834]
# >650, d[0.240,0.229], g[4.567] q[35.862]
# >655, d[0.215,0.174], g[3.318] q[35.809]
# >660, d[0.204,0.211], g[3.137] q[35.415]
# >665, d[0.182,0.171], g[3.539] q[35.247]
# >670, d[0.213,0.192], g[3.345] q[35.359]
# >675, d[0.184,0.190], g[3.246] q[35.364]
# >680, d[0.185,0.175], g[3.168] q[35.641]
# >685, d[0.192,0.204], g[3.145] q[35.043]
# >690, d[0.194,0.193], g[3.338] q[35.701]
# >695, d[0.164,0.210], g[3.784] q[35.300]
# >700, d[0.178,0.196], g[3.370] q[37.110]
# >705, d[0.241,0.206], g[3.139] q[35.598]
# >710, d[0.193,0.185], g[3.254] q[35.101]
# >715, d[0.181,0.187], g[3.171] q[35.360]
# >720, d[0.197,0.200], g[3.086] q[34.326]
# >725, d[0.180,0.177], g[3.318] q[34.943]
# >730, d[0.226,0.192], g[3.286] q[34.592]
# >735, d[0.197,0.191], g[3.262] q[34.481]
# >740, d[0.191,0.196], g[3.046] q[34.453]
# >745, d[0.179,0.180], g[3.576] q[34.309]
# >750, d[0.197,0.218], g[3.828] q[34.607]
# >755, d[0.189,0.190], g[3.168] q[34.732]
# >760, d[0.179,0.173], g[3.645] q[34.692]
# >765, d[0.214,0.182], g[3.865] q[34.653]
# >770, d[0.186,0.212], g[3.264] q[35.473]
# >775, d[0.205,0.190], g[3.426] q[34.601]
# >780, d[0.199,0.180], g[3.129] q[34.605]
# >785, d[0.207,0.199], g[3.009] q[34.054]
# >790, d[0.210,0.162], g[3.245] q[33.960]
# >795, d[0.202,0.193], g[3.355] q[33.897]
# >800, d[0.187,0.197], g[3.155] q[34.293]
# >805, d[0.196,0.189], g[3.314] q[33.941]
# >810, d[0.180,0.199], g[3.070] q[33.545]
# >815, d[0.215,0.197], g[3.320] q[33.679]
# >820, d[0.189,0.193], g[3.256] q[33.834]
# >825, d[0.202,0.193], g[2.829] q[33.878]
# >830, d[0.186,0.198], g[3.165] q[33.515]
# >835, d[0.176,0.195], g[3.449] q[33.574]
# >840, d[0.182,0.195], g[3.051] q[33.964]
# >845, d[0.189,0.206], g[3.375] q[33.612]
# >850, d[0.218,0.180], g[2.939] q[33.938]
# >855, d[0.194,0.195], g[3.772] q[33.672]
# >860, d[0.206,0.195], g[3.601] q[33.515]
# >865, d[0.186,0.160], g[3.567] q[33.829]
# >870, d[0.203,0.185], g[3.176] q[33.807]
# >875, d[0.183,0.183], g[3.199] q[33.619]
# >880, d[0.154,0.205], g[3.217] q[33.805]
# >885, d[0.208,0.186], g[3.314] q[33.717]
# >890, d[0.191,0.192], g[3.125] q[33.646]
# >895, d[0.208,0.170], g[3.457] q[33.615]
# >900, d[0.200,0.177], g[3.505] q[33.226]
# >905, d[0.205,0.188], g[3.134] q[33.178]
# >910, d[0.193,0.201], g[3.484] q[33.136]
# >915, d[0.197,0.200], g[3.638] q[33.276]
# >920, d[0.222,0.176], g[3.051] q[33.255]
# >925, d[0.191,0.192], g[3.128] q[33.579]
# >930, d[0.190,0.187], g[3.157] q[33.176]
# >935, d[0.186,0.193], g[3.044] q[33.577]
# >940, d[0.189,0.205], g[3.762] q[33.023]
# >945, d[0.198,0.177], g[3.605] q[33.064]
# >950, d[0.189,0.198], g[2.980] q[33.666]
# >955, d[0.193,0.186], g[3.318] q[33.423]
# >960, d[0.171,0.191], g[3.186] q[33.673]
# >965, d[0.190,0.198], g[3.275] q[33.363]
# >970, d[0.217,0.193], g[3.239] q[33.574]
# >975, d[0.204,0.189], g[3.116] q[33.107]
# >980, d[0.169,0.187], g[3.196] q[33.346]
# >985, d[0.191,0.191], g[3.286] q[33.422]
# >990, d[0.181,0.195], g[3.180] q[33.451]
# >995, d[0.189,0.202], g[3.155] q[33.066]
# >1000, d[0.189,0.138], g[3.495] q[33.262]
# >1005, d[0.192,0.201], g[2.988] q[33.570]
# >1010, d[0.213,0.196], g[2.924] q[33.285]
# >1015, d[0.205,0.215], g[3.330] q[33.095]
# >1020, d[0.202,0.204], g[3.206] q[33.131]
# >1025, d[0.180,0.189], g[3.256] q[33.414]
# >1030, d[0.190,0.192], g[3.151] q[33.493]
# >1035, d[0.173,0.209], g[3.906] q[32.902]
# >1040, d[0.201,0.178], g[3.720] q[33.322]
# >1045, d[0.173,0.156], g[3.715] q[33.225]
# >1050, d[0.202,0.211], g[3.534] q[33.308]
# >1055, d[0.203,0.206], g[3.528] q[33.380]
# >1060, d[0.184,0.199], g[3.765] q[33.076]
# >1065, d[0.205,0.173], g[3.531] q[32.839]
# >1070, d[0.187,0.196], g[2.931] q[33.131]
# >1075, d[0.189,0.204], g[3.307] q[33.179]
# >1080, d[0.223,0.197], g[3.207] q[33.347]
# >1085, d[0.195,0.202], g[3.802] q[33.393]
# >1090, d[0.189,0.190], g[2.993] q[33.511]
# >1095, d[0.200,0.188], g[3.125] q[32.898]
# >1100, d[0.172,0.201], g[3.246] q[33.385]
# >1105, d[0.190,0.196], g[3.316] q[33.191]
# >1110, d[0.195,0.189], g[3.569] q[33.090]
# >1115, d[0.203,0.202], g[3.225] q[33.291]
# >1120, d[0.201,0.207], g[3.385] q[33.253]
# >1125, d[0.195,0.192], g[3.369] q[32.618]
# >1130, d[0.193,0.183], g[3.041] q[32.988]
# >1135, d[0.202,0.185], g[3.130] q[32.990]
# >1140, d[0.197,0.194], g[3.116] q[32.710]
# >1145, d[0.202,0.188], g[3.330] q[32.843]
# >1150, d[0.201,0.199], g[3.175] q[33.023]
# >1155, d[0.195,0.187], g[3.244] q[33.009]
# >1160, d[0.197,0.199], g[3.219] q[32.733]
# >1165, d[0.194,0.197], g[3.251] q[32.904]
# >1170, d[0.192,0.193], g[3.466] q[32.669]
# >1175, d[0.179,0.186], g[3.266] q[32.867]
# >1180, d[0.185,0.200], g[3.088] q[32.731]
# >1185, d[0.195,0.212], g[3.290] q[32.844]
# >1190, d[0.193,0.191], g[2.959] q[32.749]
# >1195, d[0.187,0.212], g[3.174] q[32.510]
# >1200, d[0.204,0.191], g[3.068] q[32.854]
# >1205, d[0.198,0.190], g[3.239] q[32.836]
# >1210, d[0.171,0.167], g[3.339] q[32.538]
# >1215, d[0.207,0.186], g[3.264] q[32.669]
# >1220, d[0.224,0.199], g[3.361] q[32.703]
# >1225, d[0.226,0.203], g[3.342] q[32.580]
# >1230, d[0.184,0.207], g[3.042] q[33.255]
# >1235, d[0.185,0.160], g[3.421] q[32.865]
# >1240, d[0.216,0.199], g[3.260] q[32.521]
# >1245, d[0.187,0.186], g[3.096] q[33.263]
# >1250, d[0.198,0.205], g[3.150] q[32.386]
# >1255, d[0.194,0.187], g[3.236] q[32.760]
# >1260, d[0.202,0.189], g[3.406] q[32.897]
# >1265, d[0.196,0.187], g[3.034] q[32.572]
# >1270, d[0.184,0.201], g[3.412] q[32.566]
# >1275, d[0.203,0.179], g[3.037] q[32.655]
# >1280, d[0.192,0.191], g[3.023] q[32.638]
# >1285, d[0.196,0.196], g[3.299] q[32.699]
# >1290, d[0.188,0.205], g[3.382] q[32.386]
# >1295, d[0.194,0.220], g[3.546] q[32.324]
# >1300, d[0.190,0.200], g[3.132] q[32.521]
# >1305, d[0.193,0.191], g[3.198] q[32.233]
# >1310, d[0.208,0.192], g[3.002] q[32.422]
# >1315, d[0.203,0.193], g[2.997] q[32.652]
# >1320, d[0.198,0.170], g[3.234] q[32.905]
# >1325, d[0.189,0.200], g[3.291] q[32.623]
# >1330, d[0.181,0.199], g[3.193] q[32.480]
# >1335, d[0.199,0.193], g[3.399] q[32.358]
# >1340, d[0.188,0.211], g[3.746] q[32.482]
# >1345, d[0.193,0.211], g[3.093] q[32.525]
# >1350, d[0.175,0.194], g[3.057] q[32.196]
# >1355, d[0.199,0.181], g[3.126] q[32.995]
# >1360, d[0.202,0.196], g[3.204] q[32.259]
# >1365, d[0.208,0.191], g[3.230] q[32.703]
# >1370, d[0.216,0.220], g[3.562] q[32.421]
# >1375, d[0.185,0.189], g[3.092] q[32.614]
# >1380, d[0.177,0.197], g[3.232] q[32.519]
# >1385, d[0.200,0.195], g[3.271] q[32.555]
# >1390, d[0.194,0.200], g[3.332] q[32.683]
# >1395, d[0.184,0.192], g[3.136] q[32.388]
# >1400, d[0.196,0.191], g[3.202] q[32.604]
# >1405, d[0.169,0.196], g[3.004] q[32.497]
# >1410, d[0.198,0.198], g[3.351] q[32.305]
# >1415, d[0.189,0.184], g[3.244] q[32.483]
# >1420, d[0.191,0.199], g[3.236] q[32.697]
# >1425, d[0.202,0.200], g[3.106] q[32.460]
# >1430, d[0.189,0.189], g[2.948] q[32.526]
# >1435, d[0.204,0.191], g[3.219] q[32.596]
# >1440, d[0.191,0.234], g[2.981] q[32.862]
# >1445, d[0.172,0.187], g[3.183] q[32.395]
# >1450, d[0.196,0.199], g[3.415] q[32.610]
# >1455, d[0.194,0.164], g[3.259] q[32.635]
# >1460, d[0.209,0.201], g[3.225] q[32.384]
# >1465, d[0.202,0.205], g[3.486] q[32.211]
# >1470, d[0.188,0.177], g[3.554] q[32.375]
# >1475, d[0.193,0.194], g[3.217] q[32.591]
# >1480, d[0.195,0.199], g[3.196] q[32.416]
# >1485, d[0.163,0.211], g[3.119] q[32.514]
# >1490, d[0.205,0.193], g[2.990] q[32.642]
# >1495, d[0.204,0.189], g[3.175] q[32.698]
# >1500, d[0.196,0.191], g[3.054] q[32.343]
# >1505, d[0.207,0.178], g[3.197] q[32.576]
# >1510, d[0.202,0.212], g[2.875] q[32.476]
# >1515, d[0.191,0.216], g[3.195] q[32.900]
# >1520, d[0.190,0.189], g[2.827] q[32.244]
# >1525, d[0.157,0.209], g[3.962] q[32.373]
# >1530, d[0.188,0.186], g[3.107] q[32.749]
# >1535, d[0.214,0.196], g[3.184] q[32.993]
# >1540, d[0.207,0.190], g[3.072] q[32.785]
# >1545, d[0.201,0.197], g[3.081] q[32.549]
# >1550, d[0.178,0.198], g[3.171] q[32.396]
# >1555, d[0.196,0.211], g[3.346] q[32.690]
# >1560, d[0.187,0.178], g[3.283] q[32.671]
# >1565, d[0.193,0.197], g[3.105] q[32.751]
# >1570, d[0.186,0.164], g[3.152] q[32.467]
# >1575, d[0.167,0.191], g[3.510] q[32.120]
# >1580, d[0.186,0.202], g[3.254] q[32.396]
# >1585, d[0.197,0.199], g[3.239] q[32.125]
# >1590, d[0.212,0.198], g[3.161] q[32.145]
# >1595, d[0.200,0.201], g[3.001] q[32.371]
# >1600, d[0.209,0.201], g[3.030] q[32.269]
# >1605, d[0.201,0.167], g[3.600] q[32.470]
# >1610, d[0.192,0.203], g[3.409] q[32.500]
# >1615, d[0.193,0.194], g[3.287] q[32.245]
# >1620, d[0.185,0.202], g[3.290] q[32.444]
# >1625, d[0.182,0.164], g[3.399] q[32.910]
# >1630, d[0.203,0.191], g[3.159] q[32.448]
# >1635, d[0.188,0.198], g[3.037] q[31.910]
# >1640, d[0.188,0.173], g[3.414] q[32.370]
# >1645, d[0.189,0.192], g[3.176] q[32.046]
# >1650, d[0.201,0.200], g[3.499] q[32.981]
# >1655, d[0.202,0.199], g[3.231] q[32.403]
# >1660, d[0.170,0.198], g[3.315] q[32.599]
# >1665, d[0.197,0.199], g[2.962] q[32.335]
# >1670, d[0.174,0.189], g[3.276] q[32.153]
# >1675, d[0.199,0.195], g[3.200] q[32.364]
# >1680, d[0.195,0.198], g[3.147] q[32.017]
# >1685, d[0.187,0.190], g[2.985] q[32.544]
# >1690, d[0.191,0.199], g[2.927] q[32.110]
# >1695, d[0.198,0.176], g[3.413] q[32.371]
# >1700, d[0.170,0.186], g[2.952] q[32.796]
# >1705, d[0.194,0.196], g[2.870] q[32.832]
# >1710, d[0.202,0.197], g[3.163] q[32.268]
# >1715, d[0.184,0.200], g[3.045] q[32.733]
# >1720, d[0.202,0.192], g[3.385] q[32.345]
# >1725, d[0.183,0.200], g[3.298] q[32.547]
# >1730, d[0.190,0.183], g[3.043] q[32.725]
# >1735, d[0.187,0.191], g[3.084] q[32.778]
# >1740, d[0.190,0.203], g[3.308] q[32.136]
# >1745, d[0.189,0.192], g[3.142] q[32.334]
# >1750, d[0.196,0.195], g[3.059] q[32.483]
# >1755, d[0.194,0.179], g[3.375] q[32.735]
# >1760, d[0.185,0.197], g[3.171] q[32.255]
# >1765, d[0.199,0.200], g[3.190] q[32.831]
# >1770, d[0.193,0.199], g[3.249] q[32.474]
# >1775, d[0.198,0.191], g[3.275] q[32.819]
# >1780, d[0.192,0.195], g[3.590] q[32.603]
# >1785, d[0.172,0.199], g[3.204] q[33.149]
# >1790, d[0.195,0.168], g[3.374] q[32.500]
# >1795, d[0.187,0.165], g[3.196] q[32.706]
# >1800, d[0.189,0.172], g[3.293] q[32.274]
# >1805, d[0.199,0.186], g[2.851] q[32.017]
# >1810, d[0.191,0.192], g[3.100] q[32.867]
# >1815, d[0.200,0.191], g[3.029] q[32.463]
# >1820, d[0.185,0.186], g[3.057] q[32.542]
# >1825, d[0.202,0.183], g[2.985] q[32.602]
# >1830, d[0.191,0.166], g[3.491] q[32.380]
# >1835, d[0.187,0.195], g[3.243] q[32.676]
# >1840, d[0.190,0.164], g[3.258] q[32.291]
# >1845, d[0.189,0.192], g[3.099] q[32.747]
# >1850, d[0.189,0.191], g[3.461] q[32.390]
# >1855, d[0.184,0.167], g[3.295] q[33.076]
# >1860, d[0.164,0.185], g[3.347] q[32.645]
# >1865, d[0.193,0.196], g[3.500] q[32.915]
# >1870, d[0.190,0.190], g[3.015] q[32.753]
# >1875, d[0.189,0.189], g[2.711] q[32.823]
# >1880, d[0.194,0.194], g[3.156] q[32.695]
# >1885, d[0.191,0.190], g[3.249] q[32.753]
# >1890, d[0.190,0.189], g[3.340] q[32.640]
# >1895, d[0.197,0.201], g[3.209] q[32.420]
# >1900, d[0.206,0.198], g[3.265] q[32.611]
# >1905, d[0.192,0.202], g[3.087] q[32.936]
# >1910, d[0.195,0.191], g[3.268] q[32.277]
# >1915, d[0.196,0.194], g[3.112] q[32.571]
# >1920, d[0.183,0.202], g[2.946] q[32.616]
# >1925, d[0.187,0.185], g[2.893] q[32.642]
# >1930, d[0.182,0.197], g[3.162] q[32.759]
# >1935, d[0.197,0.190], g[3.032] q[32.398]
# >1940, d[0.197,0.167], g[3.409] q[32.482]
# >1945, d[0.188,0.197], g[2.996] q[32.373]
# >1950, d[0.189,0.193], g[3.172] q[32.372]
# >1955, d[0.168,0.183], g[3.335] q[32.555]
# >1960, d[0.192,0.193], g[3.169] q[33.055]
# >1965, d[0.191,0.196], g[2.978] q[32.706]
# >1970, d[0.168,0.200], g[3.066] q[32.646]
# >1975, d[0.180,0.226], g[3.683] q[32.704]
# >1980, d[0.190,0.191], g[2.971] q[32.873]
# >1985, d[0.188,0.194], g[3.318] q[32.860]
# >1990, d[0.192,0.174], g[3.555] q[32.435]
# >1995, d[0.188,0.184], g[3.178] q[32.493]
# >2000, d[0.199,0.188], g[3.148] q[32.461]
# >2005, d[0.211,0.190], g[2.973] q[32.963]
# >2010, d[0.195,0.204], g[3.046] q[32.808]
# >2015, d[0.205,0.197], g[3.250] q[32.788]
# >2020, d[0.176,0.193], g[3.174] q[32.372]
# >2025, d[0.188,0.183], g[3.300] q[32.736]
# >2030, d[0.164,0.178], g[2.963] q[32.623]
# >2035, d[0.191,0.185], g[3.173] q[33.083]
# >2040, d[0.193,0.202], g[3.418] q[33.260]
# >2045, d[0.164,0.194], g[3.288] q[32.614]
# >2050, d[0.200,0.180], g[3.339] q[32.211]
# >2055, d[0.202,0.195], g[3.460] q[32.299]
# >2060, d[0.202,0.230], g[4.193] q[32.935]
# >2065, d[0.193,0.199], g[3.088] q[32.639]
# >2070, d[0.189,0.175], g[3.300] q[32.838]
# >2075, d[0.185,0.202], g[3.005] q[32.451]
# >2080, d[0.192,0.181], g[3.238] q[32.946]
# >2085, d[0.182,0.179], g[3.188] q[32.853]
# >2090, d[0.193,0.199], g[3.028] q[32.492]
# >2095, d[0.197,0.196], g[3.346] q[32.311]
# >2100, d[0.194,0.189], g[3.233] q[33.082]
# >2105, d[0.196,0.192], g[3.071] q[32.895]
# >2110, d[0.190,0.190], g[3.162] q[32.553]
# >2115, d[0.185,0.190], g[3.191] q[33.008]
# >2120, d[0.192,0.193], g[3.494] q[33.108]
# >2125, d[0.181,0.200], g[2.899] q[32.493]
# >2130, d[0.174,0.181], g[3.143] q[32.956]
# >2135, d[0.191,0.189], g[3.311] q[32.831]
# >2140, d[0.186,0.193], g[3.098] q[32.792]
# >2145, d[0.194,0.179], g[3.252] q[32.884]
# >2150, d[0.164,0.188], g[3.214] q[32.848]
# >2155, d[0.187,0.193], g[3.064] q[32.829]
# >2160, d[0.190,0.213], g[3.047] q[33.071]
# >2165, d[0.190,0.206], g[4.563] q[32.826]
# >2170, d[0.188,0.224], g[3.999] q[32.991]
# >2175, d[0.196,0.185], g[3.155] q[32.893]
# >2180, d[0.164,0.194], g[3.321] q[33.049]
# >2185, d[0.199,0.197], g[3.072] q[33.025]
# >2190, d[0.202,0.177], g[3.254] q[33.173]
# >2195, d[0.192,0.194], g[3.227] q[33.319]
# >2200, d[0.198,0.191], g[3.129] q[33.051]
# >2205, d[0.207,0.196], g[3.044] q[33.757]
# >2210, d[0.195,0.188], g[3.247] q[32.665]
# >2215, d[0.196,0.181], g[3.013] q[33.091]
# >2220, d[0.203,0.198], g[3.023] q[32.412]
# >2225, d[0.174,0.196], g[3.434] q[32.749]
# >2230, d[0.190,0.199], g[3.252] q[32.599]
# >2235, d[0.182,0.184], g[3.035] q[32.998]
# >2240, d[0.195,0.190], g[2.947] q[33.161]
# >2245, d[0.198,0.191], g[3.198] q[33.198]
# >2250, d[0.186,0.215], g[3.110] q[33.177]
# >2255, d[0.205,0.194], g[3.182] q[33.555]
# >2260, d[0.186,0.174], g[3.329] q[33.478]
# >2265, d[0.194,0.188], g[3.031] q[32.811]
# >2270, d[0.183,0.205], g[3.203] q[32.933]
# >2275, d[0.196,0.197], g[3.148] q[33.275]
# >2280, d[0.185,0.200], g[3.396] q[33.130]
# >2285, d[0.184,0.189], g[3.076] q[33.181]
# >2290, d[0.195,0.143], g[3.644] q[32.952]
# >2295, d[0.193,0.199], g[2.916] q[33.249]
# >2300, d[0.174,0.196], g[2.904] q[32.899]
# >2305, d[0.192,0.193], g[3.239] q[33.371]
# >2310, d[0.185,0.194], g[3.201] q[32.757]
# >2315, d[0.176,0.199], g[3.420] q[33.401]
# >2320, d[0.207,0.196], g[2.917] q[32.973]
# >2325, d[0.191,0.195], g[3.137] q[32.963]
# >2330, d[0.200,0.191], g[3.161] q[33.134]
# >2335, d[0.187,0.189], g[3.224] q[33.264]
# >2340, d[0.196,0.197], g[2.958] q[33.034]
# >2345, d[0.204,0.192], g[3.059] q[33.398]
# >2350, d[0.190,0.194], g[3.121] q[32.978]
# >2355, d[0.191,0.186], g[3.169] q[32.855]
# >2360, d[0.181,0.213], g[2.750] q[33.541]
# >2365, d[0.195,0.189], g[3.134] q[32.989]
# >2370, d[0.195,0.191], g[2.946] q[32.582]
# >2375, d[0.194,0.188], g[3.040] q[32.978]
# >2380, d[0.189,0.207], g[3.083] q[33.447]
# >2385, d[0.185,0.197], g[3.300] q[33.598]
# >2390, d[0.191,0.188], g[3.016] q[32.844]
# >2395, d[0.215,0.187], g[3.151] q[33.513]
# >2400, d[0.193,0.164], g[3.210] q[33.544]
# >2405, d[0.188,0.198], g[2.937] q[33.122]
# >2410, d[0.185,0.216], g[3.716] q[32.770]
# >2415, d[0.186,0.199], g[3.396] q[33.336]
# >2420, d[0.196,0.190], g[2.960] q[32.585]
# >2425, d[0.202,0.195], g[2.888] q[32.518]
# >2430, d[0.199,0.185], g[3.617] q[33.319]
# >2435, d[0.199,0.198], g[3.171] q[32.977]
# >2440, d[0.195,0.193], g[2.931] q[33.234]
# >2445, d[0.189,0.187], g[3.139] q[33.299]
# >2450, d[0.194,0.198], g[2.844] q[33.178]
# >2455, d[0.191,0.198], g[3.214] q[33.392]
# >2460, d[0.191,0.189], g[3.166] q[33.283]
# >2465, d[0.196,0.196], g[2.998] q[33.562]
# >2470, d[0.193,0.203], g[3.437] q[33.527]
# >2475, d[0.203,0.182], g[2.970] q[32.675]
# >2480, d[0.198,0.199], g[3.366] q[33.297]
# >2485, d[0.184,0.187], g[3.370] q[33.292]
# >2490, d[0.185,0.192], g[3.035] q[33.313]
# >2495, d[0.185,0.190], g[3.164] q[32.993]
# >2500, d[0.190,0.169], g[3.527] q[33.854]
# >2505, d[0.196,0.193], g[3.182] q[33.528]
# >2510, d[0.188,0.211], g[3.236] q[32.755]
# >2515, d[0.193,0.180], g[3.141] q[33.180]
# >2520, d[0.189,0.203], g[3.179] q[33.594]
# >2525, d[0.187,0.193], g[3.027] q[33.515]
# >2530, d[0.198,0.175], g[3.555] q[32.948]
# >2535, d[0.194,0.189], g[3.418] q[32.831]
# >2540, d[0.190,0.200], g[3.289] q[33.417]
# >2545, d[0.166,0.164], g[3.293] q[33.306]
# >2550, d[0.162,0.194], g[3.037] q[33.023]
# >2555, d[0.190,0.194], g[3.114] q[33.490]
# >2560, d[0.195,0.178], g[3.527] q[33.276]
# >2565, d[0.184,0.192], g[3.040] q[33.596]
# >2570, d[0.192,0.202], g[2.981] q[33.476]
# >2575, d[0.181,0.195], g[3.276] q[33.653]
# >2580, d[0.203,0.188], g[3.283] q[33.521]
# >2585, d[0.161,0.194], g[3.175] q[33.275]
# >2590, d[0.167,0.191], g[3.132] q[33.452]
# >2595, d[0.200,0.198], g[2.981] q[33.230]
# >2600, d[0.189,0.177], g[3.068] q[33.198]
# >2605, d[0.197,0.174], g[3.454] q[33.486]
# >2610, d[0.202,0.200], g[3.372] q[33.965]
# >2615, d[0.197,0.194], g[3.403] q[33.265]
# >2620, d[0.183,0.185], g[3.320] q[33.654]
# >2625, d[0.203,0.193], g[3.075] q[34.347]
# >2630, d[0.189,0.178], g[3.250] q[34.385]
# >2635, d[0.190,0.188], g[2.936] q[33.406]
# >2640, d[0.197,0.197], g[3.117] q[33.177]
# >2645, d[0.193,0.204], g[3.199] q[33.447]
# >2650, d[0.178,0.187], g[3.231] q[33.130]
# >2655, d[0.194,0.198], g[3.141] q[33.954]
# >2660, d[0.199,0.191], g[3.213] q[33.704]
# >2665, d[0.190,0.170], g[3.282] q[33.238]
# >2670, d[0.187,0.187], g[3.300] q[34.046]
# >2675, d[0.194,0.207], g[3.306] q[33.051]
# >2680, d[0.197,0.187], g[3.168] q[33.790]
# >2685, d[0.199,0.188], g[2.868] q[33.433]
# >2690, d[0.166,0.195], g[3.083] q[33.537]
# >2695, d[0.181,0.201], g[3.003] q[33.451]
# >2700, d[0.188,0.190], g[3.035] q[33.452]
# >2705, d[0.198,0.193], g[3.304] q[33.905]
# >2710, d[0.188,0.155], g[3.424] q[34.238]
# >2715, d[0.191,0.191], g[3.145] q[34.131]
# >2720, d[0.195,0.190], g[2.959] q[33.740]
# >2725, d[0.200,0.191], g[3.354] q[33.536]
# >2730, d[0.192,0.212], g[3.892] q[33.804]
# >2735, d[0.189,0.197], g[3.096] q[33.416]
# >2740, d[0.207,0.190], g[3.092] q[33.188]
# >2745, d[0.187,0.201], g[3.035] q[33.950]
# >2750, d[0.187,0.161], g[3.381] q[33.638]
# >2755, d[0.192,0.196], g[3.278] q[33.951]
# >2760, d[0.192,0.183], g[3.125] q[33.544]
# >2765, d[0.187,0.191], g[2.974] q[33.422]
# >2770, d[0.186,0.190], g[2.949] q[33.265]
# >2775, d[0.199,0.187], g[3.077] q[33.492]
# >2780, d[0.192,0.198], g[3.414] q[34.242]
# >2785, d[0.162,0.217], g[3.571] q[33.622]
# >2790, d[0.165,0.202], g[3.404] q[33.761]
# >2795, d[0.194,0.196], g[2.967] q[33.597]
# >2800, d[0.192,0.190], g[3.215] q[34.054]
# >2805, d[0.188,0.188], g[3.242] q[33.389]
# >2810, d[0.168,0.197], g[3.134] q[33.893]
# >2815, d[0.189,0.165], g[3.292] q[33.997]
# >2820, d[0.203,0.208], g[3.627] q[33.481]
# >2825, d[0.185,0.191], g[2.891] q[33.924]
# >2830, d[0.190,0.198], g[3.328] q[34.308]
# >2835, d[0.192,0.195], g[3.003] q[34.390]
# >2840, d[0.192,0.191], g[3.286] q[33.835]
# >2845, d[0.189,0.190], g[3.045] q[33.930]
# >2850, d[0.190,0.166], g[3.603] q[33.939]
# >2855, d[0.198,0.192], g[3.163] q[33.868]
# >2860, d[0.208,0.190], g[3.978] q[34.412]
# >2865, d[0.193,0.193], g[3.228] q[34.350]
# >2870, d[0.191,0.187], g[3.155] q[33.970]
# >2875, d[0.192,0.188], g[3.416] q[33.524]
# >2880, d[0.195,0.189], g[3.116] q[33.855]
# >2885, d[0.194,0.196], g[3.142] q[33.786]
# >2890, d[0.166,0.191], g[3.030] q[33.494]
# >2895, d[0.194,0.196], g[3.101] q[33.966]
# >2900, d[0.188,0.201], g[3.012] q[33.665]
# >2905, d[0.193,0.189], g[3.167] q[34.506]
# >2910, d[0.190,0.190], g[3.090] q[34.169]
# >2915, d[0.199,0.185], g[2.677] q[33.785]
# >2920, d[0.202,0.201], g[3.374] q[34.014]
# >2925, d[0.200,0.177], g[3.607] q[34.490]
# >2930, d[0.188,0.195], g[3.313] q[34.279]
# >2935, d[0.195,0.183], g[3.838] q[33.856]
# >2940, d[0.183,0.195], g[3.194] q[33.957]
# >2945, d[0.191,0.164], g[3.410] q[33.962]
# >2950, d[0.192,0.179], g[3.158] q[34.419]
# >2955, d[0.182,0.202], g[3.008] q[34.044]
# >2960, d[0.166,0.141], g[3.659] q[33.763]
# >2965, d[0.192,0.166], g[3.456] q[34.674]
# >2970, d[0.187,0.202], g[3.178] q[33.763]
# >2975, d[0.194,0.189], g[3.270] q[34.357]
# >2980, d[0.189,0.198], g[3.227] q[33.945]
# >2985, d[0.191,0.194], g[3.114] q[34.381]
# >2990, d[0.188,0.177], g[3.239] q[34.718]
# >2995, d[0.193,0.206], g[4.035] q[34.172]
# >3000, d[0.190,0.201], g[3.086] q[34.544]
# >3005, d[0.179,0.169], g[3.351] q[34.520]
# >3010, d[0.187,0.188], g[3.099] q[34.343]
# >3015, d[0.197,0.186], g[3.171] q[35.034]
# >3020, d[0.187,0.168], g[3.418] q[34.535]
# >3025, d[0.187,0.198], g[3.233] q[34.410]
# >3030, d[0.194,0.187], g[2.967] q[34.425]
# >3035, d[0.198,0.183], g[3.259] q[34.638]
# >3040, d[0.189,0.195], g[3.117] q[34.689]
# >3045, d[0.191,0.191], g[2.670] q[34.415]
# >3050, d[0.196,0.200], g[3.218] q[34.552]
# >3055, d[0.180,0.192], g[3.241] q[34.503]
# >3060, d[0.195,0.187], g[2.857] q[35.463]
# >3065, d[0.196,0.196], g[3.196] q[34.348]
# >3070, d[0.197,0.202], g[3.282] q[34.679]
# >3075, d[0.190,0.163], g[3.233] q[34.793]
# >3080, d[0.190,0.196], g[3.272] q[34.902]
# >3085, d[0.202,0.195], g[3.007] q[34.747]
# >3090, d[0.186,0.186], g[3.041] q[34.562]
# >3095, d[0.192,0.189], g[3.232] q[34.593]
# >3100, d[0.195,0.189], g[3.041] q[35.107]
# >3105, d[0.195,0.200], g[2.742] q[34.539]
# >3110, d[0.162,0.188], g[3.260] q[34.210]
# >3115, d[0.204,0.203], g[2.971] q[34.617]
# >3120, d[0.188,0.174], g[3.519] q[34.597]
# >3125, d[0.206,0.195], g[3.268] q[34.198]
# >3130, d[0.185,0.177], g[3.832] q[33.742]
# >3135, d[0.194,0.194], g[3.023] q[34.436]
# >3140, d[0.186,0.198], g[2.937] q[34.627]
# >3145, d[0.190,0.191], g[2.909] q[34.397]
# >3150, d[0.186,0.190], g[3.079] q[34.861]
# >3155, d[0.194,0.191], g[3.454] q[34.748]
# >3160, d[0.197,0.184], g[3.184] q[34.905]
# >3165, d[0.151,0.184], g[2.936] q[34.908]
# >3170, d[0.195,0.175], g[3.313] q[35.096]
# >3175, d[0.202,0.190], g[3.111] q[34.927]
# >3180, d[0.202,0.190], g[3.195] q[34.402]
# >3185, d[0.198,0.208], g[3.578] q[34.550]
# >3190, d[0.189,0.190], g[3.001] q[34.568]
# >3195, d[0.191,0.198], g[3.204] q[34.747]
# >3200, d[0.189,0.200], g[3.701] q[35.164]
# >3205, d[0.187,0.187], g[3.944] q[35.114]
# >3210, d[0.203,0.194], g[3.174] q[35.023]
# >3215, d[0.203,0.201], g[3.105] q[34.591]
# >3220, d[0.185,0.200], g[3.084] q[34.837]
# >3225, d[0.166,0.187], g[2.999] q[34.586]
# >3230, d[0.199,0.195], g[3.125] q[34.730]
# >3235, d[0.199,0.186], g[3.263] q[35.273]
# >3240, d[0.184,0.198], g[3.082] q[35.306]
# >3245, d[0.190,0.186], g[2.960] q[34.300]
# >3250, d[0.194,0.192], g[2.943] q[34.793]
# >3255, d[0.188,0.194], g[3.103] q[34.839]
# >3260, d[0.194,0.173], g[3.699] q[35.280]
# >3265, d[0.202,0.191], g[3.303] q[34.616]
# >3270, d[0.196,0.194], g[3.115] q[34.835]
# >3275, d[0.187,0.192], g[3.021] q[35.263]
# >3280, d[0.196,0.155], g[3.673] q[34.731]
# >3285, d[0.193,0.192], g[3.184] q[34.915]
# >3290, d[0.188,0.189], g[3.145] q[34.768]
# >3295, d[0.194,0.183], g[3.397] q[35.530]
# >3300, d[0.199,0.170], g[3.495] q[34.832]
# >3305, d[0.192,0.187], g[3.316] q[34.869]
# >3310, d[0.191,0.188], g[2.999] q[35.394]
# >3315, d[0.174,0.197], g[3.325] q[34.893]
# >3320, d[0.191,0.185], g[3.263] q[34.952]
# >3325, d[0.191,0.185], g[3.384] q[35.540]
# >3330, d[0.184,0.212], g[3.016] q[35.216]
# >3335, d[0.197,0.193], g[2.942] q[35.129]
# >3340, d[0.190,0.194], g[3.161] q[35.088]
# >3345, d[0.189,0.190], g[3.154] q[35.125]
# >3350, d[0.187,0.187], g[3.204] q[35.515]
# >3355, d[0.195,0.187], g[2.956] q[35.571]
# >3360, d[0.194,0.188], g[2.850] q[35.577]
# >3365, d[0.187,0.208], g[2.930] q[35.959]
# >3370, d[0.188,0.192], g[3.193] q[34.934]
# >3375, d[0.194,0.189], g[3.071] q[35.214]
# >3380, d[0.188,0.194], g[2.822] q[35.080]
# >3385, d[0.192,0.186], g[3.087] q[34.997]
# >3390, d[0.189,0.196], g[2.988] q[35.391]
# >3395, d[0.191,0.191], g[3.071] q[34.949]
# >3400, d[0.186,0.168], g[3.505] q[35.404]
# >3405, d[0.198,0.168], g[3.321] q[35.257]
# >3410, d[0.187,0.191], g[3.122] q[35.304]
# >3415, d[0.173,0.161], g[3.510] q[35.427]
# >3420, d[0.186,0.197], g[3.237] q[35.714]
# >3425, d[0.191,0.196], g[3.071] q[35.148]
# >3430, d[0.184,0.193], g[2.959] q[34.913]
# >3435, d[0.193,0.200], g[3.114] q[35.420]
# >3440, d[0.183,0.191], g[3.159] q[35.033]
# >3445, d[0.172,0.199], g[3.678] q[35.901]
# >3450, d[0.189,0.184], g[3.205] q[35.332]
# >3455, d[0.197,0.196], g[2.922] q[35.932]
# >3460, d[0.191,0.187], g[2.882] q[36.025]
# >3465, d[0.202,0.193], g[2.956] q[35.189]
# >3470, d[0.196,0.207], g[2.891] q[35.890]
# >3475, d[0.192,0.212], g[3.368] q[35.870]
# >3480, d[0.192,0.196], g[2.959] q[35.776]
# >3485, d[0.200,0.185], g[3.459] q[36.217]
# >3490, d[0.192,0.189], g[3.128] q[36.285]
# >3495, d[0.161,0.198], g[3.221] q[36.727]
# >3500, d[0.182,0.191], g[3.142] q[35.160]
# >3505, d[0.200,0.197], g[3.205] q[35.478]
# >3510, d[0.197,0.198], g[3.293] q[35.995]
# >3515, d[0.183,0.195], g[3.039] q[36.646]
# >3520, d[0.200,0.192], g[3.325] q[35.676]
# >3525, d[0.168,0.186], g[3.231] q[35.930]
# >3530, d[0.190,0.198], g[3.053] q[34.824]
# >3535, d[0.191,0.175], g[3.895] q[35.391]
# >3540, d[0.188,0.192], g[3.172] q[35.284]
# >3545, d[0.188,0.187], g[3.135] q[35.638]
# >3550, d[0.187,0.191], g[3.415] q[36.101]
# >3555, d[0.194,0.202], g[3.221] q[35.308]
# >3560, d[0.206,0.199], g[2.951] q[36.058]
# >3565, d[0.192,0.186], g[3.176] q[35.989]
# >3570, d[0.168,0.193], g[3.505] q[35.907]
# >3575, d[0.187,0.186], g[2.859] q[35.412]
# >3580, d[0.191,0.197], g[3.052] q[35.774]
# >3585, d[0.176,0.189], g[3.392] q[35.263]
# >3590, d[0.190,0.193], g[2.872] q[35.448]
# >3595, d[0.190,0.189], g[3.196] q[35.606]
# >3600, d[0.162,0.183], g[3.036] q[35.693]
# >3605, d[0.191,0.164], g[3.253] q[34.703]
# >3610, d[0.182,0.192], g[3.172] q[35.966]
# >3615, d[0.183,0.204], g[3.051] q[36.276]
# >3620, d[0.166,0.189], g[3.286] q[35.718]
# >3625, d[0.191,0.193], g[3.001] q[36.345]
# >3630, d[0.197,0.194], g[2.933] q[36.012]
# >3635, d[0.189,0.186], g[3.198] q[35.949]
# >3640, d[0.202,0.191], g[3.086] q[36.142]
# >3645, d[0.196,0.190], g[3.129] q[36.023]
# >3650, d[0.192,0.191], g[2.905] q[35.584]
# >3655, d[0.190,0.198], g[3.384] q[35.538]
# >3660, d[0.190,0.189], g[3.354] q[35.770]
# >3665, d[0.193,0.166], g[3.272] q[34.965]
# >3670, d[0.193,0.190], g[3.086] q[35.792]
# >3675, d[0.193,0.192], g[3.039] q[36.014]
# >3680, d[0.190,0.191], g[3.879] q[35.840]
# >3685, d[0.191,0.194], g[3.000] q[35.877]
# >3690, d[0.193,0.190], g[2.975] q[35.004]
# >3695, d[0.192,0.193], g[3.250] q[35.716]
# >3700, d[0.164,0.192], g[3.052] q[35.525]
# >3705, d[0.192,0.190], g[3.277] q[36.609]
# >3710, d[0.186,0.197], g[3.120] q[35.698]
# >3715, d[0.191,0.194], g[2.900] q[35.442]
# >3720, d[0.194,0.190], g[3.201] q[36.226]
# >3725, d[0.192,0.190], g[3.074] q[36.060]
# >3730, d[0.193,0.195], g[2.886] q[36.441]
# >3735, d[0.192,0.192], g[3.014] q[36.481]
# >3740, d[0.192,0.195], g[3.035] q[36.338]
# >3745, d[0.199,0.188], g[3.059] q[36.166]
# >3750, d[0.171,0.191], g[2.943] q[36.473]
# >3755, d[0.195,0.184], g[3.029] q[35.748]
# >3760, d[0.187,0.204], g[3.277] q[35.902]
# >3765, d[0.186,0.194], g[2.982] q[36.735]
# >3770, d[0.195,0.174], g[3.605] q[35.981]
# >3775, d[0.192,0.195], g[3.316] q[35.858]
# >3780, d[0.194,0.194], g[2.941] q[36.371]
# >3785, d[0.195,0.200], g[3.086] q[35.205]
# >3790, d[0.206,0.201], g[3.123] q[35.863]
# >3795, d[0.190,0.195], g[3.087] q[36.764]
# >3800, d[0.197,0.199], g[3.153] q[34.912]
# >3805, d[0.189,0.198], g[2.930] q[36.521]
# >3810, d[0.186,0.187], g[3.276] q[36.167]
# >3815, d[0.192,0.188], g[3.152] q[36.526]
# >3820, d[0.192,0.189], g[3.091] q[36.151]
# >3825, d[0.192,0.187], g[3.192] q[36.654]
# >3830, d[0.185,0.171], g[3.435] q[36.312]
# >3835, d[0.184,0.185], g[3.216] q[36.336]
# >3840, d[0.169,0.191], g[3.189] q[36.026]
# >3845, d[0.196,0.191], g[3.025] q[36.391]
# >3850, d[0.182,0.197], g[3.037] q[37.106]
# >3855, d[0.190,0.189], g[3.101] q[37.197]
# >3860, d[0.202,0.199], g[3.666] q[37.256]
# >3865, d[0.191,0.165], g[3.270] q[36.428]
# >3870, d[0.193,0.193], g[3.173] q[36.444]
# >3875, d[0.188,0.188], g[3.152] q[36.424]
# >3880, d[0.207,0.185], g[2.970] q[36.778]
# >3885, d[0.190,0.200], g[2.992] q[36.276]
# >3890, d[0.164,0.192], g[3.137] q[37.297]
# >3895, d[0.199,0.199], g[3.201] q[36.667]
# >3900, d[0.190,0.191], g[3.207] q[36.580]
# >3905, d[0.193,0.193], g[3.213] q[35.542]
# >3910, d[0.189,0.191], g[3.042] q[35.601]
# >3915, d[0.191,0.193], g[3.136] q[35.709]
# >3920, d[0.188,0.189], g[2.970] q[35.767]
# >3925, d[0.141,0.197], g[3.069] q[36.375]
# >3930, d[0.195,0.192], g[3.239] q[36.199]
# >3935, d[0.190,0.190], g[3.212] q[36.895]
# >3940, d[0.189,0.209], g[2.975] q[36.589]
# >3945, d[0.194,0.200], g[3.063] q[37.452]
# >3950, d[0.187,0.211], g[3.008] q[37.195]
# >3955, d[0.189,0.192], g[3.250] q[36.323]
# >3960, d[0.191,0.221], g[3.492] q[37.002]
# >3965, d[0.191,0.193], g[3.100] q[37.332]
# >3970, d[0.187,0.183], g[2.945] q[37.088]
# >3975, d[0.188,0.190], g[3.137] q[37.643]
# >3980, d[0.184,0.193], g[3.282] q[36.891]
# >3985, d[0.199,0.205], g[3.289] q[36.359]
# >3990, d[0.194,0.194], g[3.179] q[37.186]
# >3995, d[0.203,0.197], g[3.237] q[37.090]
# >4000, d[0.190,0.196], g[2.918] q[37.604]
# >4005, d[0.199,0.190], g[3.280] q[36.756]
# >4010, d[0.193,0.191], g[3.059] q[37.151]
# >4015, d[0.192,0.193], g[3.127] q[36.733]
# >4020, d[0.200,0.194], g[3.321] q[36.554]
# >4025, d[0.192,0.199], g[3.080] q[36.877]
# >4030, d[0.191,0.188], g[3.158] q[37.863]
# >4035, d[0.173,0.192], g[3.247] q[36.532]
# >4040, d[0.189,0.161], g[3.281] q[36.733]
# >4045, d[0.188,0.171], g[3.369] q[36.390]
# >4050, d[0.173,0.196], g[3.066] q[37.832]
# >4055, d[0.196,0.192], g[3.049] q[37.694]
# >4060, d[0.192,0.193], g[3.074] q[36.966]
# >4065, d[0.165,0.195], g[3.139] q[36.536]
# >4070, d[0.190,0.193], g[3.208] q[36.537]
# >4075, d[0.189,0.191], g[3.010] q[36.697]
# >4080, d[0.195,0.192], g[2.918] q[36.877]
# >4085, d[0.191,0.202], g[3.096] q[36.966]
# >4090, d[0.196,0.187], g[3.063] q[37.149]
# >4095, d[0.192,0.192], g[3.065] q[37.351]
# >4100, d[0.191,0.195], g[3.154] q[37.037]
# >4105, d[0.196,0.196], g[3.122] q[36.481]
# >4110, d[0.189,0.197], g[2.986] q[37.143]
# >4115, d[0.187,0.188], g[3.018] q[37.662]
# >4120, d[0.191,0.193], g[3.220] q[36.756]
# >4125, d[0.197,0.200], g[3.401] q[37.501]
# >4130, d[0.186,0.193], g[3.027] q[36.737]
# >4135, d[0.199,0.190], g[3.161] q[37.590]
# >4140, d[0.186,0.192], g[3.111] q[36.609]
# >4145, d[0.189,0.194], g[3.098] q[37.467]
# >4150, d[0.188,0.193], g[2.883] q[37.170]
# >4155, d[0.189,0.199], g[3.002] q[36.470]
# >4160, d[0.208,0.195], g[2.901] q[37.246]
# >4165, d[0.189,0.166], g[3.504] q[38.015]
# >4170, d[0.165,0.190], g[3.416] q[37.363]
# >4175, d[0.196,0.192], g[3.142] q[37.648]
# >4180, d[0.190,0.138], g[3.652] q[37.649]
# >4185, d[0.189,0.203], g[3.128] q[37.383]
# >4190, d[0.191,0.203], g[3.231] q[36.969]
# >4195, d[0.166,0.171], g[3.474] q[36.772]
# >4200, d[0.193,0.195], g[3.303] q[36.942]
# >4205, d[0.175,0.188], g[3.091] q[37.862]
# >4210, d[0.191,0.190], g[3.036] q[37.321]
# >4215, d[0.200,0.164], g[3.522] q[37.814]
# >4220, d[0.205,0.182], g[3.471] q[37.894]
# >4225, d[0.188,0.197], g[3.066] q[37.149]
# >4230, d[0.165,0.195], g[3.086] q[37.588]
# >4235, d[0.190,0.195], g[2.975] q[37.946]
# >4240, d[0.193,0.189], g[2.984] q[37.850]
# >4245, d[0.209,0.192], g[2.795] q[37.309]
# >4250, d[0.167,0.186], g[3.141] q[37.593]
# >4255, d[0.188,0.178], g[3.107] q[37.410]
# >4260, d[0.189,0.185], g[3.073] q[37.571]
# >4265, d[0.192,0.188], g[2.972] q[37.180]
# >4270, d[0.186,0.192], g[3.139] q[37.685]
# >4275, d[0.192,0.191], g[3.079] q[37.071]
# >4280, d[0.172,0.193], g[3.200] q[37.241]
# >4285, d[0.192,0.191], g[3.119] q[38.722]
# >4290, d[0.184,0.189], g[3.190] q[37.922]
# >4295, d[0.206,0.193], g[3.096] q[37.854]
# >4300, d[0.164,0.194], g[3.126] q[38.083]
# >4305, d[0.194,0.186], g[2.919] q[37.384]
# >4310, d[0.170,0.197], g[3.029] q[38.053]
# >4315, d[0.190,0.197], g[3.153] q[38.559]
# >4320, d[0.193,0.171], g[3.560] q[38.244]
# >4325, d[0.190,0.190], g[3.129] q[38.131]
# >4330, d[0.202,0.195], g[3.272] q[37.523]
# >4335, d[0.191,0.184], g[3.103] q[37.856]
# >4340, d[0.165,0.192], g[3.097] q[38.061]
# >4345, d[0.192,0.163], g[3.475] q[37.850]
# >4350, d[0.163,0.181], g[3.073] q[38.184]
# >4355, d[0.206,0.163], g[3.517] q[39.261]
# >4360, d[0.200,0.193], g[2.942] q[39.218]
# >4365, d[0.185,0.197], g[2.756] q[38.612]
# >4370, d[0.167,0.191], g[3.182] q[38.496]
# >4375, d[0.202,0.199], g[3.043] q[39.098]
# >4380, d[0.191,0.191], g[3.025] q[37.620]
# >4385, d[0.170,0.190], g[3.152] q[37.995]
# >4390, d[0.196,0.201], g[2.879] q[38.317]
# >4395, d[0.189,0.195], g[3.552] q[39.056]
# >4400, d[0.189,0.187], g[3.012] q[38.207]
# >4405, d[0.193,0.182], g[3.048] q[37.567]
# >4410, d[0.191,0.193], g[3.273] q[37.772]
# >4415, d[0.167,0.184], g[3.077] q[37.983]
# >4420, d[0.205,0.167], g[3.418] q[38.363]
# >4425, d[0.192,0.158], g[3.354] q[38.294]
# >4430, d[0.167,0.192], g[3.173] q[38.940]
# >4435, d[0.192,0.187], g[3.122] q[38.147]
# >4440, d[0.172,0.193], g[3.095] q[39.065]
# >4445, d[0.194,0.192], g[2.993] q[38.809]
# >4450, d[0.189,0.208], g[3.258] q[38.794]
# >4455, d[0.193,0.191], g[2.955] q[38.159]
# >4460, d[0.199,0.170], g[3.457] q[38.801]
# >4465, d[0.201,0.196], g[2.919] q[38.331]
# >4470, d[0.193,0.195], g[3.126] q[38.080]
# >4475, d[0.198,0.198], g[3.084] q[38.506]
# >4480, d[0.189,0.198], g[3.065] q[38.778]
# >4485, d[0.196,0.160], g[3.340] q[38.372]
# >4490, d[0.195,0.198], g[3.013] q[38.838]
# >4495, d[0.188,0.201], g[3.278] q[37.555]
# >4500, d[0.190,0.209], g[3.416] q[38.557]
# >4505, d[0.192,0.182], g[3.113] q[39.265]
# >4510, d[0.186,0.193], g[3.114] q[37.648]
# >4515, d[0.192,0.191], g[3.119] q[38.552]
# >4520, d[0.198,0.190], g[3.210] q[38.125]
# >4525, d[0.194,0.205], g[3.187] q[37.658]
# >4530, d[0.194,0.191], g[2.937] q[38.295]
# >4535, d[0.187,0.194], g[3.018] q[37.229]
# >4540, d[0.185,0.193], g[2.993] q[38.643]
# >4545, d[0.163,0.191], g[3.045] q[38.017]
# >4550, d[0.194,0.197], g[3.195] q[37.878]
# >4555, d[0.189,0.200], g[3.534] q[38.372]
# >4560, d[0.197,0.166], g[3.589] q[39.472]
# >4565, d[0.188,0.182], g[3.116] q[39.949]
# >4570, d[0.199,0.197], g[2.930] q[38.544]
# >4575, d[0.191,0.165], g[3.274] q[38.665]
# >4580, d[0.189,0.184], g[3.176] q[38.825]
# >4585, d[0.185,0.195], g[3.055] q[38.799]
# >4590, d[0.189,0.190], g[3.053] q[38.245]
# >4595, d[0.188,0.191], g[3.175] q[38.411]
# >4600, d[0.182,0.190], g[3.062] q[39.250]
# >4605, d[0.163,0.198], g[3.123] q[39.074]
# >4610, d[0.203,0.196], g[3.302] q[38.711]
# >4615, d[0.182,0.198], g[3.222] q[38.705]
# >4620, d[0.198,0.190], g[2.994] q[38.603]
# >4625, d[0.192,0.197], g[3.088] q[39.394]
# >4630, d[0.183,0.184], g[3.180] q[38.601]
# >4635, d[0.196,0.165], g[3.342] q[39.140]
# >4640, d[0.193,0.190], g[3.150] q[38.680]
# >4645, d[0.191,0.189], g[3.213] q[38.643]
# >4650, d[0.164,0.186], g[2.993] q[39.014]
# >4655, d[0.185,0.189], g[3.137] q[39.959]
# >4660, d[0.166,0.196], g[3.052] q[38.452]
# >4665, d[0.194,0.195], g[3.333] q[39.784]
# >4670, d[0.194,0.179], g[3.152] q[39.484]
# >4675, d[0.188,0.197], g[3.098] q[38.107]
# >4680, d[0.176,0.195], g[2.953] q[39.194]
# >Saved: generated_plot_4680.png, model_4680.h5, and gan_model_4680.h5
# >4685, d[0.175,0.189], g[3.090] q[39.524]
# >4690, d[0.193,0.199], g[3.298] q[39.393]
# >4695, d[0.195,0.162], g[3.444] q[40.199]
# >4700, d[0.194,0.164], g[3.294] q[39.283]
# >4705, d[0.190,0.194], g[3.250] q[40.099]
# >4710, d[0.193,0.194], g[3.078] q[39.631]
# >4715, d[0.189,0.194], g[3.237] q[38.736]
# >4720, d[0.195,0.198], g[3.167] q[39.794]
# >4725, d[0.194,0.182], g[3.092] q[39.231]
# >4730, d[0.195,0.166], g[3.418] q[39.984]
# >4735, d[0.194,0.167], g[3.367] q[39.638]
# >4740, d[0.191,0.185], g[3.053] q[40.242]
# >4745, d[0.189,0.197], g[3.062] q[38.653]
# >4750, d[0.164,0.194], g[3.193] q[39.311]
# >4755, d[0.197,0.190], g[3.073] q[39.752]
# >4760, d[0.189,0.163], g[3.447] q[39.929]
# >4765, d[0.207,0.195], g[3.095] q[38.978]
# >4770, d[0.189,0.165], g[3.251] q[39.598]
# >4775, d[0.203,0.197], g[2.824] q[39.691]
# >4780, d[0.189,0.165], g[3.137] q[39.890]
# >4785, d[0.164,0.190], g[3.124] q[39.958]
# >4790, d[0.191,0.194], g[3.072] q[38.824]
# >4795, d[0.166,0.200], g[2.839] q[40.064]
# >4800, d[0.187,0.188], g[3.008] q[40.279]
# >4805, d[0.205,0.188], g[2.924] q[38.590]
# >4810, d[0.186,0.180], g[3.238] q[38.956]
# >4815, d[0.194,0.185], g[3.135] q[38.752]
# >4820, d[0.189,0.194], g[3.260] q[39.670]
# >4825, d[0.191,0.191], g[3.068] q[39.826]
# >4830, d[0.197,0.192], g[3.111] q[39.646]
# >4835, d[0.190,0.200], g[3.236] q[40.520]
# >4840, d[0.189,0.185], g[3.148] q[40.421]
# >4845, d[0.197,0.161], g[3.367] q[39.377]
# >4850, d[0.194,0.198], g[2.943] q[39.770]
# >4855, d[0.193,0.200], g[3.045] q[39.789]
# >4860, d[0.188,0.189], g[3.001] q[40.684]
# >4865, d[0.186,0.160], g[3.445] q[40.102]
# >4870, d[0.189,0.190], g[3.159] q[40.073]
# >4875, d[0.189,0.184], g[3.131] q[40.274]
# >4880, d[0.173,0.192], g[3.064] q[39.828]
# >4885, d[0.191,0.187], g[3.130] q[39.603]
# >4890, d[0.187,0.208], g[3.022] q[40.413]
# >4895, d[0.213,0.137], g[3.328] q[39.879]
# >4900, d[0.165,0.190], g[3.173] q[39.636]
# >4905, d[0.195,0.185], g[3.043] q[39.668]
# >4910, d[0.194,0.191], g[3.290] q[40.666]
# >4915, d[0.190,0.170], g[3.162] q[41.229]
# >4920, d[0.193,0.193], g[3.081] q[40.119]
# >4925, d[0.194,0.184], g[3.005] q[40.489]
# >4930, d[0.166,0.199], g[3.193] q[39.637]
# >4935, d[0.188,0.193], g[3.069] q[39.532]
# >4940, d[0.204,0.167], g[3.428] q[40.946]
# >4945, d[0.192,0.190], g[3.036] q[39.967]
# >4950, d[0.176,0.189], g[3.195] q[40.664]
# >4955, d[0.186,0.167], g[3.301] q[40.387]
# >4960, d[0.192,0.185], g[3.105] q[40.163]
# >4965, d[0.190,0.198], g[2.775] q[40.435]
# >4970, d[0.191,0.190], g[3.188] q[40.815]
# >4975, d[0.173,0.197], g[2.918] q[40.563]
# >4980, d[0.195,0.191], g[3.131] q[39.928]
# >4985, d[0.188,0.184], g[3.298] q[40.450]
# >4990, d[0.168,0.199], g[2.956] q[40.647]
# >4995, d[0.184,0.183], g[3.133] q[41.650]
# >5000, d[0.195,0.192], g[3.049] q[40.410]
# >5005, d[0.191,0.186], g[3.160] q[40.569]
# >5010, d[0.186,0.193], g[3.202] q[40.135]
# >5015, d[0.196,0.188], g[2.992] q[41.680]
# >5020, d[0.197,0.195], g[2.902] q[40.581]
# >5025, d[0.186,0.174], g[3.333] q[41.162]
# >5030, d[0.188,0.190], g[2.929] q[41.541]
# >5035, d[0.184,0.200], g[3.248] q[41.199]
# >5040, d[0.169,0.191], g[3.151] q[41.935]
# >5045, d[0.164,0.197], g[2.880] q[40.130]
# >5050, d[0.189,0.181], g[3.094] q[41.124]
# >5055, d[0.192,0.200], g[2.962] q[41.483]
# >5060, d[0.169,0.185], g[3.138] q[41.231]
# >5065, d[0.186,0.197], g[2.957] q[41.032]
# >5070, d[0.197,0.202], g[3.295] q[41.192]
# >5075, d[0.190,0.200], g[3.102] q[41.012]
# >5080, d[0.194,0.162], g[3.340] q[40.714]
# >5085, d[0.190,0.194], g[3.254] q[41.066]
# >5090, d[0.193,0.192], g[3.143] q[40.591]
# >5095, d[0.187,0.191], g[3.068] q[41.487]
# >5100, d[0.193,0.204], g[3.281] q[41.248]
# >5105, d[0.194,0.186], g[2.922] q[42.390]
# >5110, d[0.189,0.192], g[3.078] q[42.070]
# >5115, d[0.187,0.165], g[3.301] q[42.626]
# >5120, d[0.200,0.208], g[3.205] q[42.717]
# >5125, d[0.187,0.188], g[2.990] q[41.642]
# >5130, d[0.196,0.191], g[2.872] q[41.720]
# >5135, d[0.198,0.201], g[3.276] q[42.330]
# >5140, d[0.198,0.190], g[3.067] q[41.418]
# >5145, d[0.191,0.191], g[3.066] q[41.747]
# >5150, d[0.198,0.190], g[3.029] q[41.779]
# >5155, d[0.187,0.189], g[3.002] q[41.973]
# >5160, d[0.191,0.158], g[3.297] q[42.213]
# >5165, d[0.197,0.192], g[3.094] q[42.217]
# >5170, d[0.193,0.202], g[3.039] q[43.188]
# >5175, d[0.192,0.170], g[3.275] q[42.197]
# >5180, d[0.187,0.210], g[3.222] q[42.381]
# >5185, d[0.193,0.197], g[3.407] q[42.230]
# >5190, d[0.167,0.198], g[3.178] q[42.015]
# >5195, d[0.188,0.195], g[2.915] q[42.277]
# >5200, d[0.190,0.196], g[3.043] q[42.487]
# >5205, d[0.187,0.174], g[3.204] q[42.016]
# >5210, d[0.190,0.191], g[3.179] q[41.485]
# >5215, d[0.197,0.189], g[3.385] q[42.250]
# >5220, d[0.186,0.194], g[2.904] q[43.071]
# >5225, d[0.191,0.189], g[3.218] q[43.113]
# >5230, d[0.196,0.191], g[3.222] q[42.825]
# >5235, d[0.201,0.194], g[2.975] q[43.500]
# >5240, d[0.189,0.162], g[3.255] q[43.192]
# >5245, d[0.194,0.189], g[3.092] q[42.361]
# >5250, d[0.142,0.203], g[3.271] q[43.142]
# >5255, d[0.189,0.168], g[3.324] q[42.635]
# >5260, d[0.187,0.156], g[3.433] q[43.086]
# >5265, d[0.166,0.164], g[3.364] q[43.240]
# >5270, d[0.187,0.195], g[3.186] q[43.400]
# >5275, d[0.204,0.182], g[3.141] q[44.179]
# >5280, d[0.188,0.190], g[3.076] q[43.063]
# >5285, d[0.170,0.195], g[3.150] q[43.292]
# >5290, d[0.191,0.187], g[3.129] q[43.379]
# >5295, d[0.191,0.173], g[3.310] q[43.778]
# >5300, d[0.189,0.194], g[3.151] q[43.033]
# >5305, d[0.190,0.191], g[3.067] q[43.331]
# >5310, d[0.191,0.187], g[3.099] q[43.070]
# >5315, d[0.191,0.196], g[3.153] q[43.043]
# >5320, d[0.191,0.189], g[3.050] q[44.022]
# >5325, d[0.192,0.189], g[3.090] q[43.868]
# >5330, d[0.193,0.201], g[3.046] q[43.370]
# >5335, d[0.191,0.170], g[3.316] q[43.519]
# >5340, d[0.186,0.190], g[3.037] q[42.838]
# >5345, d[0.192,0.191], g[3.080] q[43.145]
# >5350, d[0.189,0.198], g[3.266] q[42.690]
# >5355, d[0.191,0.193], g[3.019] q[43.964]
# >5360, d[0.183,0.190], g[3.101] q[43.975]
# >5365, d[0.187,0.186], g[3.170] q[43.449]
# >5370, d[0.191,0.198], g[3.080] q[43.694]
# >5375, d[0.165,0.194], g[3.054] q[43.690]
# >5380, d[0.191,0.190], g[3.092] q[43.996]
# >5385, d[0.191,0.189], g[3.103] q[43.666]
# >5390, d[0.191,0.198], g[3.073] q[43.982]
# >5395, d[0.191,0.194], g[2.967] q[44.755]
# >5400, d[0.186,0.193], g[3.090] q[44.420]
# >5405, d[0.207,0.190], g[3.186] q[44.348]
# >5410, d[0.194,0.191], g[3.222] q[44.149]
# >5415, d[0.189,0.189], g[3.110] q[44.347]
# >5420, d[0.184,0.186], g[3.101] q[44.541]
# >5425, d[0.163,0.196], g[3.249] q[45.212]
# >5430, d[0.183,0.190], g[3.080] q[44.154]
# >5435, d[0.189,0.190], g[3.062] q[44.996]
# >5440, d[0.192,0.192], g[3.067] q[44.573]
# >5445, d[0.184,0.191], g[2.978] q[44.430]
# >5450, d[0.193,0.165], g[3.213] q[44.613]
# >5455, d[0.190,0.196], g[2.993] q[44.981]
# >5460, d[0.188,0.191], g[3.097] q[44.685]
# >5465, d[0.197,0.184], g[3.105] q[44.803]
# >5470, d[0.190,0.195], g[3.258] q[45.540]
# >5475, d[0.186,0.190], g[2.974] q[44.491]
# >5480, d[0.188,0.195], g[3.012] q[44.599]
# >5485, d[0.198,0.204], g[3.318] q[44.302]
# >5490, d[0.163,0.189], g[3.086] q[43.589]
# >5495, d[0.185,0.190], g[3.069] q[43.923]
# >5500, d[0.204,0.200], g[3.098] q[45.275]
# >5505, d[0.191,0.189], g[3.034] q[45.089]
# >5510, d[0.187,0.198], g[3.015] q[44.781]
# >5515, d[0.192,0.197], g[3.159] q[44.117]
# >5520, d[0.193,0.191], g[3.157] q[45.205]
# >5525, d[0.191,0.201], g[3.029] q[44.960]
# >5530, d[0.187,0.169], g[3.277] q[44.328]
# >5535, d[0.193,0.189], g[3.112] q[45.071]
# >5540, d[0.184,0.192], g[3.148] q[45.266]
# >5545, d[0.189,0.193], g[3.046] q[45.960]
# >5550, d[0.197,0.188], g[3.075] q[43.601]
# >5555, d[0.186,0.185], g[3.094] q[44.869]
# >5560, d[0.195,0.171], g[3.340] q[44.594]
# >5565, d[0.193,0.191], g[3.069] q[45.489]
# >5570, d[0.194,0.187], g[3.123] q[44.734]
# >5575, d[0.188,0.197], g[3.279] q[45.807]
# >5580, d[0.187,0.191], g[2.971] q[46.097]
# >5585, d[0.195,0.199], g[2.908] q[45.009]
# >5590, d[0.188,0.190], g[3.175] q[45.587]
# >5595, d[0.190,0.170], g[3.417] q[45.530]
# >5600, d[0.193,0.187], g[3.215] q[45.833]
# >5605, d[0.191,0.196], g[3.068] q[45.024]
# >5610, d[0.191,0.191], g[2.998] q[45.118]
# >5615, d[0.191,0.167], g[3.490] q[45.449]
# >5620, d[0.189,0.190], g[3.162] q[45.428]
# >5625, d[0.167,0.192], g[3.052] q[45.908]
# >5630, d[0.182,0.196], g[3.059] q[45.897]
# >5635, d[0.193,0.190], g[3.077] q[45.511]
# >5640, d[0.198,0.191], g[3.095] q[45.230]
# >5645, d[0.190,0.192], g[3.124] q[45.291]
# >5650, d[0.171,0.184], g[3.123] q[45.281]
# >5655, d[0.167,0.170], g[3.340] q[45.984]
# >5660, d[0.188,0.189], g[3.061] q[44.901]
# >5665, d[0.189,0.187], g[3.113] q[45.476]
# >5670, d[0.193,0.193], g[3.226] q[45.789]
# >5675, d[0.197,0.188], g[3.117] q[45.094]
# >5680, d[0.187,0.190], g[3.071] q[45.480]
# >5685, d[0.165,0.182], g[3.022] q[45.268]
# >5690, d[0.192,0.192], g[3.050] q[45.055]
# >5695, d[0.191,0.189], g[3.043] q[45.035]
# >5700, d[0.164,0.196], g[3.025] q[44.418]
# >5705, d[0.183,0.183], g[3.066] q[45.814]
# >5710, d[0.189,0.192], g[3.065] q[45.118]
# >5715, d[0.194,0.199], g[3.021] q[45.610]
# >5720, d[0.190,0.197], g[3.273] q[45.012]
# >5725, d[0.174,0.187], g[3.147] q[45.657]
# ...
# >29560, d[0.167,0.191], g[3.063] q[99.754]
# >29565, d[0.190,0.189], g[3.071] q[112.602]
# >29570, d[0.193,0.191], g[3.067] q[97.292]
# >29575, d[0.189,0.190], g[3.028] q[128.377]
# >29580, d[0.190,0.167], g[3.220] q[134.471]
# >29585, d[0.191,0.188], g[3.144] q[109.528]
# >29590, d[0.189,0.191], g[3.049] q[109.317]
# >29595, d[0.189,0.191], g[3.139] q[125.150]
# >29600, d[0.188,0.191], g[3.052] q[107.068]
# >29605, d[0.190,0.187], g[3.077] q[128.389]
# >29610, d[0.190,0.191], g[3.050] q[102.780]
# >29615, d[0.188,0.188], g[3.064] q[119.002]
# >29620, d[0.191,0.163], g[3.184] q[108.810]
# >29625, d[0.188,0.189], g[3.049] q[101.607]
# >29630, d[0.191,0.189], g[3.125] q[114.171]
# >29635, d[0.190,0.188], g[2.995] q[105.050]
# >29640, d[0.189,0.190], g[3.065] q[108.936]
# >29645, d[0.191,0.188], g[3.128] q[101.167]
# >29650, d[0.189,0.189], g[2.964] q[99.687]
# >29655, d[0.191,0.190], g[3.082] q[117.450]
# >29660, d[0.190,0.193], g[2.983] q[103.308]
# >29665, d[0.192,0.189], g[3.043] q[115.161]
# >29670, d[0.191,0.191], g[3.078] q[103.062]
# >29675, d[0.190,0.167], g[3.217] q[116.014]
# >29680, d[0.188,0.190], g[3.079] q[99.275]
# >29685, d[0.189,0.144], g[3.493] q[109.762]
# >29690, d[0.189,0.191], g[3.105] q[122.015]
# >29695, d[0.188,0.190], g[3.067] q[119.269]
# >29700, d[0.187,0.167], g[3.293] q[112.779]
# >29705, d[0.190,0.188], g[3.060] q[104.421]
# >29710, d[0.189,0.193], g[3.076] q[94.805]
# >29715, d[0.192,0.191], g[3.111] q[104.885]
# >29720, d[0.190,0.190], g[3.026] q[107.769]
# >29725, d[0.191,0.189], g[3.081] q[133.868]
# >29730, d[0.190,0.189], g[3.047] q[95.110]
# >29735, d[0.189,0.191], g[3.026] q[100.502]
# >29740, d[0.189,0.189], g[3.106] q[102.498]
# >29745, d[0.188,0.191], g[3.049] q[115.301]
# >29750, d[0.189,0.188], g[3.040] q[105.199]
# >29755, d[0.166,0.166], g[3.247] q[110.347]
# >29760, d[0.190,0.191], g[3.179] q[115.994]
# >29765, d[0.188,0.191], g[3.125] q[110.396]
# >29770, d[0.190,0.192], g[3.103] q[111.501]
# >29775, d[0.188,0.190], g[3.010] q[126.731]
# >29780, d[0.190,0.196], g[3.131] q[104.521]
# >29785, d[0.189,0.190], g[3.055] q[109.023]
# >29790, d[0.188,0.189], g[3.073] q[103.662]
# >29795, d[0.187,0.194], g[3.101] q[142.284]
# >29800, d[0.167,0.188], g[3.134] q[107.678]
# >29805, d[0.192,0.188], g[3.061] q[98.117]
# >29810, d[0.189,0.185], g[3.077] q[111.469]
# >29815, d[0.190,0.189], g[3.057] q[112.582]
# >29820, d[0.189,0.188], g[3.059] q[109.591]
# >29825, d[0.191,0.189], g[3.047] q[109.788]
# >29830, d[0.165,0.190], g[3.049] q[122.452]
# >29835, d[0.189,0.192], g[3.039] q[120.737]
# >29840, d[0.163,0.189], g[3.009] q[108.612]
# >29845, d[0.188,0.163], g[3.336] q[102.987]
# >29850, d[0.189,0.191], g[3.066] q[112.202]
# >29855, d[0.194,0.194], g[3.080] q[97.884]
# >29860, d[0.190,0.190], g[3.036] q[136.469]
# >29865, d[0.188,0.188], g[3.096] q[127.283]
# >29870, d[0.190,0.190], g[3.041] q[111.201]
# >29875, d[0.165,0.166], g[3.205] q[109.583]
# >29880, d[0.188,0.189], g[3.069] q[117.093]
# >29885, d[0.189,0.189], g[3.074] q[104.123]
# >29890, d[0.191,0.188], g[3.182] q[120.322]
# >29895, d[0.189,0.190], g[3.061] q[112.145]
# >29900, d[0.190,0.188], g[3.031] q[100.104]
# >29905, d[0.189,0.190], g[3.076] q[117.207]
# >29910, d[0.189,0.188], g[3.112] q[100.130]
# >29915, d[0.189,0.186], g[3.040] q[116.425]
# >29920, d[0.189,0.193], g[3.035] q[108.104]
# >29925, d[0.190,0.190], g[3.068] q[129.029]
# >29930, d[0.188,0.187], g[3.031] q[124.537]
# >29935, d[0.191,0.164], g[3.240] q[114.877]
# >29940, d[0.189,0.188], g[3.115] q[107.640]
# >29945, d[0.189,0.190], g[3.070] q[132.205]
# >29950, d[0.167,0.191], g[3.002] q[105.258]
# >29955, d[0.191,0.195], g[3.102] q[100.246]
# >29960, d[0.191,0.188], g[3.147] q[101.696]
# >29965, d[0.187,0.190], g[3.116] q[96.034]
# >29970, d[0.192,0.190], g[3.031] q[103.189]
# >29975, d[0.191,0.187], g[3.077] q[98.575]
# >29980, d[0.170,0.192], g[3.016] q[127.279]
# >29985, d[0.187,0.187], g[3.065] q[105.555]
# >29990, d[0.189,0.190], g[3.076] q[135.504]
# >29995, d[0.188,0.194], g[3.081] q[112.241]
# >30000, d[0.188,0.191], g[3.067] q[113.327]
# >30005, d[0.188,0.166], g[3.256] q[116.706]
# >30010, d[0.191,0.189], g[3.013] q[105.955]
# >30015, d[0.194,0.192], g[3.064] q[126.663]
# >30020, d[0.189,0.188], g[3.055] q[113.896]
# >30025, d[0.165,0.189], g[2.966] q[96.962]
# >30030, d[0.189,0.190], g[3.023] q[120.602]
# >30035, d[0.190,0.188], g[3.077] q[119.409]
# >30040, d[0.190,0.189], g[3.033] q[108.814]
# >30045, d[0.188,0.187], g[3.086] q[123.183]
# >30050, d[0.189,0.191], g[3.068] q[96.118]
# >30055, d[0.190,0.188], g[3.048] q[101.355]
# >30060, d[0.168,0.190], g[3.003] q[116.992]
# >30065, d[0.188,0.189], g[3.044] q[122.537]
# >30070, d[0.191,0.192], g[3.052] q[100.882]
# >30075, d[0.189,0.189], g[3.060] q[102.247]
# >30080, d[0.189,0.191], g[3.078] q[100.153]
# >30085, d[0.189,0.167], g[3.285] q[101.663]
# >30090, d[0.189,0.189], g[3.136] q[110.717]
# >30095, d[0.190,0.189], g[3.025] q[115.384]
# >30100, d[0.191,0.190], g[3.064] q[115.128]
# >30105, d[0.190,0.165], g[3.308] q[105.988]
# >30110, d[0.187,0.190], g[2.998] q[127.005]
# >30115, d[0.190,0.190], g[3.090] q[107.535]
# >30120, d[0.191,0.165], g[3.281] q[98.976]
# >30125, d[0.189,0.164], g[3.309] q[110.460]
# >30130, d[0.188,0.164], g[3.222] q[102.771]
# >30135, d[0.190,0.188], g[3.089] q[119.831]
# >30140, d[0.189,0.190], g[3.036] q[124.608]
# >30145, d[0.190,0.190], g[3.077] q[128.109]
# >30150, d[0.190,0.191], g[3.097] q[105.231]
# >30155, d[0.188,0.190], g[3.009] q[114.148]
# >30160, d[0.188,0.166], g[3.281] q[105.051]
# >30165, d[0.188,0.189], g[3.093] q[170.682]
# >30170, d[0.192,0.166], g[3.182] q[108.231]
# >30175, d[0.192,0.187], g[3.060] q[119.329]
# >30180, d[0.192,0.170], g[3.354] q[103.921]
# >30185, d[0.166,0.189], g[3.007] q[102.165]
# >30190, d[0.191,0.191], g[3.064] q[113.098]
# >30195, d[0.189,0.167], g[3.276] q[122.502]
# >30200, d[0.189,0.191], g[3.073] q[101.898]
# >30205, d[0.192,0.191], g[3.091] q[110.465]
# >30210, d[0.167,0.190], g[3.031] q[95.832]
# >30215, d[0.165,0.190], g[3.058] q[130.759]
# >30220, d[0.190,0.191], g[3.099] q[128.279]
# >30225, d[0.189,0.189], g[3.046] q[111.377]
# >30230, d[0.189,0.190], g[3.088] q[104.794]
# >30235, d[0.193,0.190], g[2.999] q[138.661]
# >30240, d[0.165,0.188], g[3.058] q[114.806]
# >30245, d[0.192,0.191], g[3.163] q[130.807]
# >30250, d[0.188,0.190], g[3.115] q[106.573]
# >30255, d[0.190,0.188], g[3.018] q[111.588]
# >30260, d[0.187,0.189], g[3.016] q[110.915]
# >30265, d[0.189,0.189], g[3.047] q[101.048]
# >30270, d[0.190,0.167], g[3.294] q[115.503]
# >30275, d[0.189,0.188], g[3.078] q[122.758]
# >30280, d[0.190,0.161], g[3.214] q[114.003]
# >30285, d[0.189,0.189], g[3.041] q[111.151]
# >30290, d[0.189,0.186], g[3.021] q[130.894]
# >30295, d[0.190,0.191], g[3.084] q[109.673]
# >30300, d[0.191,0.193], g[3.064] q[107.001]
# >30305, d[0.190,0.187], g[3.180] q[114.003]
# >30310, d[0.189,0.191], g[3.025] q[116.190]
# >30315, d[0.187,0.188], g[3.105] q[106.783]
# >30320, d[0.191,0.190], g[3.066] q[108.076]
# >30325, d[0.190,0.193], g[3.069] q[107.624]
# >30330, d[0.166,0.193], g[2.962] q[105.272]
# >30335, d[0.166,0.189], g[3.069] q[118.128]
# >30340, d[0.189,0.192], g[2.992] q[106.801]
# >30345, d[0.189,0.190], g[3.074] q[109.249]
# >30350, d[0.189,0.189], g[3.066] q[108.940]
# >30355, d[0.166,0.168], g[3.258] q[112.601]
# >30360, d[0.190,0.189], g[3.093] q[117.351]
# >30365, d[0.189,0.192], g[3.080] q[142.841]
# >30370, d[0.189,0.189], g[3.072] q[112.251]
# >30375, d[0.188,0.189], g[3.033] q[123.921]
# >30380, d[0.191,0.164], g[3.242] q[104.608]
# >30385, d[0.189,0.191], g[3.050] q[115.891]
# >30390, d[0.192,0.191], g[3.130] q[116.135]
# >30395, d[0.166,0.192], g[3.028] q[107.762]
# >30400, d[0.165,0.188], g[2.995] q[125.235]
# >30405, d[0.190,0.190], g[3.074] q[98.906]
# >30410, d[0.189,0.188], g[3.076] q[136.269]
# >30415, d[0.187,0.188], g[3.118] q[128.289]
# >30420, d[0.190,0.164], g[3.333] q[115.715]
# >30425, d[0.189,0.166], g[3.257] q[97.850]
# >30430, d[0.189,0.193], g[3.046] q[119.399]
# >30435, d[0.189,0.185], g[3.116] q[119.438]
# >30440, d[0.194,0.193], g[3.032] q[110.285]
# >30445, d[0.188,0.191], g[3.076] q[121.766]
# >30450, d[0.190,0.162], g[3.281] q[127.298]
# >30455, d[0.162,0.193], g[3.041] q[115.133]
# >30460, d[0.188,0.187], g[2.988] q[108.826]
# >30465, d[0.190,0.189], g[3.060] q[117.897]
# >30470, d[0.189,0.191], g[3.046] q[107.289]
# >30475, d[0.191,0.164], g[3.257] q[107.670]
# >30480, d[0.187,0.192], g[3.064] q[120.413]
# >30485, d[0.192,0.186], g[3.086] q[119.722]
# >30490, d[0.191,0.182], g[3.106] q[99.854]
# >30495, d[0.188,0.185], g[3.113] q[112.871]
# >30500, d[0.190,0.194], g[3.049] q[125.130]
# >30505, d[0.190,0.194], g[3.080] q[119.434]
# >30510, d[0.190,0.165], g[3.266] q[111.591]
# >30515, d[0.189,0.191], g[3.089] q[117.246]
# >30520, d[0.190,0.197], g[3.069] q[121.532]
# >30525, d[0.189,0.168], g[3.261] q[119.829]
# >30530, d[0.190,0.190], g[3.073] q[101.900]
# >30535, d[0.191,0.191], g[3.055] q[116.039]
# >30540, d[0.191,0.188], g[3.016] q[103.057]
# >30545, d[0.190,0.187], g[3.108] q[107.137]
# >30550, d[0.193,0.192], g[3.078] q[111.206]
# >30555, d[0.189,0.188], g[3.020] q[112.935]
# >30560, d[0.190,0.164], g[3.250] q[110.453]
# >30565, d[0.191,0.188], g[3.090] q[101.908]
# >30570, d[0.189,0.166], g[3.257] q[109.672]
# >30575, d[0.189,0.189], g[3.045] q[142.924]
# >30580, d[0.167,0.190], g[3.075] q[114.830]
# >30585, d[0.190,0.191], g[3.048] q[110.596]
# >30590, d[0.191,0.166], g[3.230] q[128.274]
# >30595, d[0.188,0.166], g[3.289] q[111.921]
# >30600, d[0.188,0.145], g[3.482] q[124.228]
# >30605, d[0.166,0.188], g[3.026] q[124.944]
# >30610, d[0.187,0.191], g[3.111] q[113.665]
# >30615, d[0.166,0.191], g[3.049] q[140.181]
# >30620, d[0.189,0.189], g[3.093] q[115.046]
# >30625, d[0.190,0.189], g[3.050] q[140.589]
# >30630, d[0.188,0.184], g[2.991] q[114.476]
# >30635, d[0.189,0.188], g[3.082] q[113.421]
# >30640, d[0.189,0.166], g[3.246] q[105.652]
# >30645, d[0.185,0.187], g[3.062] q[139.455]
# >30650, d[0.160,0.187], g[3.052] q[101.322]
# >30655, d[0.160,0.171], g[3.320] q[117.141]
# >30660, d[0.213,0.211], g[3.331] q[124.425]
# >30665, d[0.192,0.188], g[3.026] q[113.256]
# >30670, d[0.193,0.191], g[3.048] q[106.282]
# >30675, d[0.191,0.191], g[3.138] q[137.840]
# >30680, d[0.190,0.188], g[3.028] q[94.208]
# >30685, d[0.189,0.189], g[3.091] q[96.183]
# >30690, d[0.189,0.191], g[3.104] q[100.879]
# >30695, d[0.192,0.192], g[3.069] q[110.858]
# >30700, d[0.190,0.190], g[3.066] q[99.946]
# >30705, d[0.189,0.191], g[3.055] q[116.172]
# >30710, d[0.165,0.188], g[3.027] q[120.246]
# >30715, d[0.188,0.166], g[3.255] q[125.098]
# >30720, d[0.189,0.190], g[2.996] q[108.372]
# >30725, d[0.189,0.190], g[3.007] q[124.567]
# >30730, d[0.190,0.165], g[3.317] q[105.684]
# >30735, d[0.190,0.190], g[2.971] q[112.895]
# >30740, d[0.187,0.190], g[3.080] q[107.407]
# >30745, d[0.190,0.189], g[3.112] q[133.551]
# >30750, d[0.188,0.190], g[2.999] q[110.723]
# >30755, d[0.190,0.188], g[3.055] q[120.227]
# >30760, d[0.187,0.187], g[3.067] q[118.214]
# >30765, d[0.191,0.187], g[3.072] q[113.325]
# >30770, d[0.190,0.192], g[3.119] q[121.666]
# >30775, d[0.191,0.186], g[3.056] q[112.138]
# >30780, d[0.190,0.190], g[3.114] q[105.272]
# >30785, d[0.189,0.186], g[3.056] q[110.074]
# >30790, d[0.189,0.186], g[3.099] q[108.606]
# >30795, d[0.190,0.192], g[3.085] q[102.661]
# >30800, d[0.191,0.187], g[3.066] q[102.582]
# >30805, d[0.189,0.193], g[3.094] q[108.698]
# >30810, d[0.167,0.188], g[3.056] q[150.785]
# >30815, d[0.190,0.191], g[3.037] q[105.713]
# >30820, d[0.189,0.189], g[3.067] q[110.115]
# >30825, d[0.189,0.188], g[3.066] q[107.150]
# >30830, d[0.189,0.167], g[3.207] q[110.096]
# >30835, d[0.190,0.191], g[3.089] q[110.044]
# >30840, d[0.189,0.191], g[2.977] q[110.272]
# >30845, d[0.190,0.188], g[3.111] q[101.144]
# >30850, d[0.189,0.192], g[3.086] q[109.571]
# >30855, d[0.188,0.192], g[3.075] q[135.448]
# >30860, d[0.189,0.194], g[3.131] q[113.476]
# >30865, d[0.189,0.189], g[3.045] q[102.466]
# >30870, d[0.189,0.166], g[3.247] q[116.306]
# >30875, d[0.190,0.186], g[3.077] q[151.773]
# >30880, d[0.190,0.190], g[3.052] q[119.875]
# >30885, d[0.188,0.186], g[3.065] q[102.667]
# >30890, d[0.191,0.190], g[3.082] q[157.559]
# >30895, d[0.186,0.189], g[3.020] q[122.480]
# >30900, d[0.191,0.188], g[3.110] q[109.162]
# >30905, d[0.191,0.191], g[3.049] q[99.741]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-8c2706bccfde> in <module>
# ----> 1 gan.train(gen_model, discr_model, infogan_model, img_train, n_epochs=100)
#
# <ipython-input-5-0d390bc4384d> in train(self, gen_model, discr_model, infogan_model, dataset, n_epochs)
#     262             X_real, y_real = self.generate_real_samples(dataset, int(self.batch_size))
#     263             # update discriminator and q model weights
# --> 264             d_loss1 = discr_model.train_on_batch(X_real, y_real)
#     265             # generate 'fake' examples
#     266             X_fake, y_fake = self.generate_fake_samples(gen_model, int(self.batch_size))
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    1723       iterator = data_adapter.single_batch_iterator(self.distribute_strategy, x,
#    1724                                                     y, sample_weight,
# -> 1725                                                     class_weight)
#    1726       self.train_function = self.make_train_function()
#    1727       logs = self.train_function(iterator)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/data_adapter.py in single_batch_iterator(strategy, x, y, sample_weight, class_weight)
#    1516     dataset = dataset.map(_make_class_weight_map_fn(class_weight))
#    1517   dataset = strategy.experimental_distribute_dataset(dataset)
# -> 1518   return iter(dataset)
#    1519
#    1520
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     420     if context.executing_eagerly() or ops.inside_function():
#     421       with ops.colocate_with(self._variant_tensor):
# --> 422         return iterator_ops.OwnedIterator(self)
#     423     else:
#     424       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     680       if (components is not None or element_spec is not None):
#     681         raise ValueError(error_message)
# --> 682       self._create_iterator(dataset)
#     683
#     684   def _create_iterator(self, dataset):
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     684   def _create_iterator(self, dataset):
#     685     # pylint: disable=protected-access
# --> 686     dataset = dataset._apply_options()
#     687
#     688     # Store dataset reference to ensure that dataset is alive when this iterator
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in _apply_options(self)
#     397       dataset = _OptimizeDataset(dataset, graph_rewrites.enabled,
#     398                                  graph_rewrites.disabled,
# --> 399                                  graph_rewrites.default, graph_rewrite_configs)
#     400
#     401     # (4) Apply stats aggregator options
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, optimizations_enabled, optimizations_disabled, optimizations_default, optimization_configs)
#    4581         self._optimizations_default,
#    4582         optimization_configs=optimization_configs,
# -> 4583         **self._flat_structure)
#    4584
#    4585     super(_OptimizeDataset, self).__init__(input_dataset, variant_tensor)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/gen_dataset_ops.py in optimize_dataset_v2(input_dataset, optimizations_enabled, optimizations_disabled, optimizations_default, output_types, output_shapes, optimization_configs, name)
#    4023         optimizations_disabled, optimizations_default, "output_types",
#    4024         output_types, "output_shapes", output_shapes, "optimization_configs",
# -> 4025         optimization_configs)
#    4026       return _result
#    4027     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_cat, n_samples, digit):
	# generate points in the latent space
	z_latent = randn(latent_dim * n_samples)
	# reshape into a batch of inputs for the network
	z_latent = z_latent.reshape(n_samples, latent_dim)
	# define categorical codes
	cat_codes = asarray([digit for _ in range(n_samples)])
	# one hot encode
	cat_codes = to_categorical(cat_codes, num_classes=n_cat)
	# concatenate latent points and control codes
	z_input = hstack((z_latent, cat_codes))
	return [z_input, cat_codes]
 
# create and save a plot of generated images
def save_plot(saved_img):
  pyplot.rcParams["figure.figsize"] = (20,10)
  for j in range(saved_img.shape[1]):
    for i in range(saved_img.shape[0]):
      # define subplot
      pyplot.subplot(saved_img.shape[1], saved_img.shape[0], (i+1)+(10*j))
      # turn off axis
      pyplot.axis('off')
      # plot raw pixel data
      pyplot.imshow(saved_img[i, j, :, :, :])
      pyplot.title('Digit={}'.format(i))
  pyplot.show()
 
# load model
model = load_model('/kaggle/working/model_23400.h5')
# number of categorical control codes
n_cat = 10
# size of the latent space
latent_dim = 64
# number of examples to generate
n_samples = 5
# define digit
digit = 1
saved_img=[]
z_input, _ = generate_latent_points(latent_dim, n_cat, n_samples, digit)
for digit in range(0,10):
  for i in range(z_input.shape[0]):
    z_input[i][-10:]=to_categorical(digit, num_classes=n_cat)
  # generate points in latent space and control codes
  # predict outputs
  X = model.predict(z_input)
  X = (X + 1) / 2.0

  saved_img.append(X)
saved_img=np.array(saved_img)
# plot the result
save_plot(saved_img)
